# %% [markdown]
# ---
# execute:
#   echo: true
#   enabled: false
#   output: true
#   warning: false
# format:
#     html:
#         code-fold: false
# ---

# %% [markdown]
# # Detect malware (RF unnormed-2-0-0-0)

# %% [markdown]
# The model deployment is done in two stages: I. tune the model, II. turn on the malware detection (on the data collected in B1 and B2 periods respectively, described in the timeline @fig-timeline)
#
# ![Timeline](../../imgs/timeline.png)
#
# ### Stage I: Model tuning
#
# On this state we fit the scaler on the data collected in B1 period, to be used later on the second stage

# %%
#| echo: false
#| output: false
basepath = "/home/root/"

# %%
#| echo: false
#| output: false
import os
os.environ["MODIN_ENGINE"] = "dask"
import modin.pandas as pd
import numpy as np

pd.set_option("display.max_columns", None)

# %%
from detect_common import *

# %%
#| output: false
p1version = "v6"
p2version = "v7"
p3version = "v5"

# %%
model = 'RF'
normed = True
skips_and_weights = [2,4,0,0]

# %%
# Parameters
model = "RF"
normed = False
skips_and_weights = [2, 0, 0, 0]

# %%
import dateutil.parser

df_b1 = pd.read_feather("cached/v5_1.ft")
# Out:
# UserWarning: Dask execution environment not yet initialized. Initializing...
# To remove this warning, run the following python code before doing dataframe operations:
#
#     from distributed import Client
#
#     client = Client()
#
# UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 43021 instead
# 2023-03-25 11:07:33,804 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-bk4v5z5y', purging
# 2023-03-25 11:07:33,806 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-h7_43x4v', purging
# 2023-03-25 11:07:33,806 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-wkyo0wh4', purging
# 2023-03-25 11:07:33,807 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-qig1s17z', purging
# 2023-03-25 11:07:33,807 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-1l3d2z0k', purging
# 2023-03-25 11:07:33,807 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-tf7z7m6b', purging
# 2023-03-25 11:07:33,808 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-8hkg6cl3', purging
# 2023-03-25 11:07:33,808 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-k_ovu2js', purging
# 2023-03-25 11:07:33,809 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-p4dex2dv', purging
# 2023-03-25 11:07:33,809 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-nov2dbju', purging
# 2023-03-25 11:07:33,809 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-1_a6lry3', purging
# 2023-03-25 11:07:33,809 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-pvs5xw7v', purging

# %%
path_doh_ips_androids = basepath + "datasets/flubot20230323/data/v5_benign_doh_ips.csv"
path_doh_ips_general = "doh_resolver_ip.csv"
full_list = get_doh_ips(path_doh_ips_androids) + get_doh_ips(path_doh_ips_general)

cp = CacheableProcessing(100, 100, full_list)
df_b1_p = cp.process(df_b1, f"cached/v5_1.p3.{p3version}.cp.ft")
# Out:
# UserWarning: `Series.tolist` is not currently supported by PandasOnDask, defaulting to pandas implementation.
# Please refer to https://modin.readthedocs.io/en/stable/supported_apis/defaulting_to_pandas.html for explanation.
# UserWarning: `Series.tolist` is not currently supported by PandasOnDask, defaulting to pandas implementation.
# UserWarning: Defaulting to pandas implementation.
# Reason: `lines` argument not supported
# FutureWarning: the 'numpy' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'numpy'

# %%
from joblib import dump, load

name = (
    ('normed-' if normed else 'unnormed-') + 
    '-'.join(str(p) for p in skips_and_weights)
)

clf = load(f'models/{model}-mix-1-p-{name}.p1.{p1version}.p2.{p2version}.joblib')

# %%
pp_b1 = PreProcessing(normed, *skips_and_weights)

df_b1_pp = pp_b1.process(
    df_b1_p,
    f"cached/p3.{p3version}.pp.{model}-{name}.saved", 
    fit_new_scaler=True
)
# Out:
# UserWarning: Defaulting to pandas implementation.
# Reason: `lines` argument not supported
# FutureWarning: the 'numpy' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'numpy'
# UserWarning: Defaulting to pandas implementation.
# Reason: `lines` argument not supported
# FutureWarning: the 'numpy' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'numpy'
# UserWarning: Defaulting to pandas implementation.
# Reason: `lines` argument not supported
# FutureWarning: the 'numpy' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'numpy'

# %%
pp_b1.store_scaler(
    f"cached/p3.{p3version}.pp.{model}-{name}.scaler"
)

# %% [markdown]
# ### Stage II: Malware detection
#
# On this state we turn on the malware detection, provisioning the model with the scaler trained before. For malware detection we use the data trained in B2 period.

# %%
df_b2 = pd.read_feather("cached/v5_2.ft")

# %%
cp = CacheableProcessing(100, 100, full_list)
df_b2_p = cp.process(df_b2, f"cached/v5_2.p3.{p3version}.cp.ft")
# Out:
# UserWarning: Defaulting to pandas implementation.
# Reason: `lines` argument not supported
# FutureWarning: the 'numpy' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'numpy'

# %%
pp_b2 = PreProcessing(normed, *skips_and_weights)
pp_b2.load_scaler(
    f"cached/p3.{p3version}.pp.{model}-{name}.scaler"
)
df_b2_pp, df_b2_pp_features, df_b2_pp_labels = pp_b2.process(
    df_b2_p,
    f"cached/b2.p3.{p3version}.pp.{model}-{name}.saved", 
    fit_new_scaler=False  # use scaler trained in B1
)
# Out:
# UserWarning: Defaulting to pandas implementation.
# Reason: `lines` argument not supported
# FutureWarning: the 'numpy' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'numpy'
# UserWarning: Defaulting to pandas implementation.
# Reason: `lines` argument not supported
# FutureWarning: the 'numpy' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'numpy'
# UserWarning: Defaulting to pandas implementation.
# Reason: `lines` argument not supported
# FutureWarning: the 'numpy' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'numpy'

# %%
def predict(pp, clf, threshold, df_pp, df_orig):
    """
    pp: PreProcessing object
    clf: classifier
    threshold: >=threshold for positive (DoH) class
    df_pp: preprocessed dataframe
    df_orig: unprocessed dataframe
    """
    df_pp2 = df_pp.copy()

    df_pp2["IsDoHPredicted"] = (clf.predict_proba(df_pp2[pp.feature_fields])[:,1] >= threshold).astype(bool)

    df_orig2 = df_orig.copy()
    # fill predicted to the original dataframe
    df_orig2["IsDoHPredicted"] = df_pp2["IsDoHPredicted"]
    # non-443 rows will be NaN, replace with False
    df_orig2["IsDoHPredicted"] = df_orig2["IsDoHPredicted"].fillna(False)

    return df_orig2

# %%
results_df = pd.read_feather(f"cached/robustness.balanced_mix-results.p3.{p3version}.ft")
results_df["skips_and_weights"] = results_df["skips_and_weights"].apply(str)
model, normed, skips_and_weights_str, auc, fprs, tprs, thresholds = results_df[
    (results_df["model"] == model) & (results_df["normed"] == normed) & (results_df["skips_and_weights"] == str(np.array(skips_and_weights)))
].iloc[0]

# %%
data = {}
for sensitivity in [0.8, 0.9]:
    threshold = [threshold for tpr, threshold in zip(tprs, thresholds) if tpr >= sensitivity][0]
    df_pred = predict(pp_b2, clf, threshold, df_b2_pp, df_b2)
    data[sensitivity] = {
        'df': df_pred,  # dataframe with predicted values,
        'threshold': threshold,
    }

# %%
def calc(df_n):
    def rate(df_h):
        dns_packets = df_h[df_h["IsDoHPredicted"] == True]["uint32 PACKETS"].sum()  # outgoing packets
        non_dns_ips = set(df_h[df_h["IsDoHPredicted"] == False]["ipaddr SRC_IP"].unique()).union(
            set(df_h[df_h["IsDoHPredicted"] == False]["ipaddr DST_IP"].unique()))
        rate = float(dns_packets) / (1.0 + len(non_dns_ips))
        return {"dns_packets": dns_packets, "non_dns": len(non_dns_ips), "rate": rate, "rate_log": np.log(rate)}

    return pd.DataFrame({ ip: rate(grp) for ip, grp in df_n.groupby(["ipaddr SRC_IP"]) }).T.reset_index()

# %% [markdown]
# #### Calculate ratio on the whole dataset

# %%
for sensitivity, value in data.items():
    print(sensitivity)
    df_pred = value["df"]
    local_df = df_pred[df_pred["ipaddr SRC_IP"].str.startswith("192.168")]
    display(calc(local_df))
# Out:
# 0.8
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# RuntimeWarning: divide by zero encountered in log
# 2023-03-25 11:10:16,145 - distributed.worker - ERROR - Exception during execution of task lambda-dbea7a0ec229d75a4ad729df90bd676b.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'apply_func-6bc0efc2-be18-4a1d-ab30-8a8d774a2bd8'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'apply_func-6bc0efc2-be18-4a1d-ab30-8a8d774a2bd8'
# RuntimeWarning: divide by zero encountered in log
# UserWarning: Distributing <class 'dict'> object. This may take some time.
#            index  dns_packets  non_dns       rate  rate_log
# 0    192.168.1.1          0.0      2.0   0.000000      -inf
# 1  192.168.2.149      95366.0   4935.0  19.320502  2.961167
# 2  192.168.2.217        573.0     19.0  28.650000  3.355153
# 3  192.168.2.249      24721.0   3870.0   6.386205  1.854140
# 4   192.168.2.42          0.0      5.0   0.000000      -inf
# 0.9
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# RuntimeWarning: divide by zero encountered in log
# 2023-03-25 11:11:10,537 - distributed.worker - ERROR - Exception during execution of task lambda-0d0949753877ba4d467c566367ec7ba5.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'apply_func-16010c85-4e95-4504-b141-3facc9927fdd'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'apply_func-16010c85-4e95-4504-b141-3facc9927fdd'
# 2023-03-25 11:11:32,809 - distributed.worker - ERROR - Exception during execution of task lambda-16436e90d79d0073be7e9ba027ce4bcb.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-2a3d4861-9de3-4ce3-92b4-fbc5a8f92512'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-2a3d4861-9de3-4ce3-92b4-fbc5a8f92512'
# 2023-03-25 11:11:53,436 - distributed.worker - ERROR - Exception during execution of task lambda-276874877d1ab743c26672623d16fa15.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'apply_func-cdb2f91f-e228-49a8-8f29-b4411581fc95'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'apply_func-cdb2f91f-e228-49a8-8f29-b4411581fc95'
# RuntimeWarning: divide by zero encountered in log
# UserWarning: Distributing <class 'dict'> object. This may take some time.
#            index  dns_packets  non_dns         rate  rate_log
# 0    192.168.1.1          0.0      2.0     0.000000      -inf
# 1  192.168.2.149     120731.0   4901.0    24.628927  3.203922
# 2  192.168.2.217      24193.0     19.0  1209.650000  7.098086
# 3  192.168.2.249      41263.0   3856.0    10.698211  2.370077
# 4   192.168.2.42          0.0      5.0     0.000000      -inf

# %% [markdown]
# #### Split into time windows

# %%
min_ts = df_b2["time TIME_FIRST"].apply(dateutil.parser.parse).min()
min_ts
# Out:
# Timestamp('2023-03-23 14:50:04.316951')

# %%
local_ips = df_b2[df_b2["ipaddr SRC_IP"].str.startswith("192.168")]["ipaddr SRC_IP"].unique().tolist()
local_ips
# Out:
# 2023-03-25 11:12:48,871 - distributed.worker - ERROR - Exception during execution of task lambda-e3265f3934990801c07f22cb64957280.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'apply_func-296d1cc3-16da-4101-8865-3594253b03af'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'apply_func-296d1cc3-16da-4101-8865-3594253b03af'
# ['192.168.2.249',
#  '192.168.2.149',
#  '192.168.2.42',
#  '192.168.2.217',
#  '192.168.1.1']

# %%
f = '3min'

for sensitivity, value in data.items():
    print(sensitivity)

    df_pred = value["df"]
    local_df = df_pred[df_pred["ipaddr SRC_IP"].str.startswith("192.168")].copy()
    local_df["time TIME_FIRST"] = local_df["time TIME_FIRST"].apply(dateutil.parser.parse)
    
    calc_ips = {}

    a1_t = local_df.set_index(["time TIME_FIRST"])

    df_resample = a1_t.groupby(pd.Grouper(freq=f, origin=min_ts)).first()
    times = df_resample.index.tolist()
    ranges = list(zip(times, times[1:]))

    df_calcs = []
    for ran in ranges:
        df_ran = a1_t[(a1_t.index > ran[0]) & (a1_t.index < ran[1])]
        df_calc = calc(df_ran)
        df_calc["ts"] = ran[0]
        df_calcs.append(df_calc)

    value["df_calc"] = pd.concat(df_calcs).reset_index(drop=True)
# Out:
# 0.8
# UserWarning: `DataFrame.groupby_on_multiple_columns` is not currently supported by PandasOnDask, defaulting to pandas implementation.
# FutureWarning: The `squeeze` parameter is deprecated and will be removed in a future version.
# UserWarning: Distributing <class 'pandas.core.frame.DataFrame'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# RuntimeWarning: divide by zero encountered in log
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 11:13:21,433 - distributed.worker - ERROR - Exception during execution of task lambda-873e61fca715782d8ea0366cfab8a30f.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-387687b9-1259-4656-b785-286686d14545'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-387687b9-1259-4656-b785-286686d14545'
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 11:13:26,833 - distributed.worker - ERROR - Exception during execution of task lambda-fcdce556a95eb697325310345b686cc9.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-ebff2a99-f443-48ca-8e1f-41fda5256cc3'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-ebff2a99-f443-48ca-8e1f-41fda5256cc3'
# 2023-03-25 11:13:28,585 - distributed.worker - ERROR - Exception during execution of task lambda-d1fc51669fb9c73b7c2d38af808d0e61.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-705a8a40-d43d-45af-b8d0-dd4b237ef6d5'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-705a8a40-d43d-45af-b8d0-dd4b237ef6d5'
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# RuntimeWarning: divide by zero encountered in log
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 11:13:41,427 - distributed.worker - ERROR - Exception during execution of task lambda-c1dcef879e180d61decc37edcf2d11a3.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-7094ce85-1b3f-456f-868a-7b1b1c86758c'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func

# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-8450c576-3668-4dd7-880c-5552de28e96e'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-8450c576-3668-4dd7-880c-5552de28e96e'
# 2023-03-25 11:18:16,687 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 11:18:24,280 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 11:18:31,266 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2023-03-25 11:18:32,796 - distributed.worker - ERROR - Exception during execution of task lambda-e244cc9c7b1f104feeeeaea09c6fdb5d.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-a9d009c9-e318-4237-af66-30a552ec65f6'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-a9d009c9-e318-4237-af66-30a552ec65f6'
# 2023-03-25 11:18:38,314 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 11:18:44,331 - distributed.worker - ERROR - Exception during execution of task lambda-2ddc1bd0011d6b8a28957188e6b668e8.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-b59ffd54-20a5-4228-8c15-f5a4dde7c98c'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-b59ffd54-20a5-4228-8c15-f5a4dde7c98c'
# 2023-03-25 11:18:45,339 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2023-03-25 11:18:52,552 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# RuntimeWarning: divide by zero encountered in log
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 11:18:59,584 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2023-03-25 11:19:06,741 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 11:19:14,080 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2023-03-25 11:19:14,540 - distributed.worker - ERROR - Exception during execution of task lambda-4e21377ff603f1d653b2da47fba190e1.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
# ...
# 2023-03-25 11:23:59,098 - distributed.scheduler - WARNING - Worker tcp://127.0.0.1:39193 failed to acquire keys: {'function-18f56d70148948e98e94636489ac385b': ('tcp://127.0.0.1:36365', 'tcp://127.0.0.1:43633', 'tcp://127.0.0.1:35133', 'tcp://127.0.0.1:39067', 'tcp://127.0.0.1:32987', 'tcp://127.0.0.1:44429', 'tcp://127.0.0.1:34111', 'tcp://127.0.0.1:36897', 'tcp://127.0.0.1:38581', 'tcp://127.0.0.1:45309', 'tcp://127.0.0.1:40551', 'tcp://127.0.0.1:45207', 'tcp://127.0.0.1:43659', 'tcp://127.0.0.1:36561', 'tcp://127.0.0.1:34753', 'tcp://127.0.0.1:37081', 'tcp://127.0.0.1:32897', 'tcp://127.0.0.1:46487', 'tcp://127.0.0.1:40907', 'tcp://127.0.0.1:44713', 'tcp://127.0.0.1:39517', 'tcp://127.0.0.1:36879', 'tcp://127.0.0.1:40127', 'tcp://127.0.0.1:34187', 'tcp://127.0.0.1:44255', 'tcp://127.0.0.1:42537', 'tcp://127.0.0.1:45069')}
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# 2023-03-25 11:24:01,387 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 11:24:06,436 - distributed.worker - ERROR - Exception during execution of task lambda-0d0d8008bf8e0a84b815fc466fee7bbd.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-305fef8b-1b1d-439d-821b-4b202f6e4b62'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-305fef8b-1b1d-439d-821b-4b202f6e4b62'
# 2023-03-25 11:24:08,610 - distributed.worker - ERROR - Exception during execution of task lambda-7e869d959c50b4dc4453e4d39dd24019.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'apply_func-a89508b6-8619-4f8b-a278-88c1a24d6f82'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'apply_func-a89508b6-8619-4f8b-a278-88c1a24d6f82'
# 2023-03-25 11:24:10,698 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 11:24:14,881 - distributed.worker - ERROR - Exception during execution of task lambda-9884d1c3aa93f18a5d2f162842f27f9c.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-997b3cf0-1196-408c-925a-836f3698a15c'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-997b3cf0-1196-408c-925a-836f3698a15c'
# 2023-03-25 11:24:20,464 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 11:24:30,056 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2023-03-25 11:24:34,753 - distributed.worker - ERROR - Exception during execution of task lambda-fb85f19dbdb957eb68ee97071e86beaa.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-0fcb3354-ef6c-4651-9815-514d112562db'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-0fcb3354-ef6c-4651-9815-514d112562db'
# RuntimeWarning: divide by zero encountered in log
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 11:24:40,445 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2023-03-25 11:24:41,733 - distributed.worker - ERROR - Exception during execution of task lambda-75b90f488089c5ccace7e3f8f4018428.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-0c545f4f-6127-4176-a0f8-74fc7034b1a2'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-0c545f4f-6127-4176-a0f8-74fc7034b1a2'
# 2023-03-25 11:24:47,718 - distributed.worker - ERROR - Exception during execution of task lambda-c0f97d8b3b6b196215bdde2c4fc6ebca.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-788e58fb-dd6a-482d-a3fb-89fcce1e9c2a'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-788e58fb-dd6a-482d-a3fb-89fcce1e9c2a'
# 2023-03-25 11:24:50,223 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 11:24:59,764 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 11:25:09,899 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2023-03-25 11:25:10,705 - distributed.worker - ERROR - Exception during execution of task lambda-6b435a0c038348d2ef8973a33caafd7b.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-adc032ff-9ed1-49a9-9e29-816f8bb2c8de'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-adc032ff-9ed1-49a9-9e29-816f8bb2c8de'
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 11:25:20,468 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2023-03-25 11:25:25,637 - distributed.worker - ERROR - Exception during execution of task lambda-0f383720a3a8a05c639fd648185e27f2.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-55fedd23-dc5e-43c1-a061-45d475d795f7'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-55fedd23-dc5e-43c1-a061-45d475d795f7'
# RuntimeWarning: divide by zero encountered in log
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 11:25:28,133 - distributed.worker - ERROR - Exception during execution of task lambda-add52702b2a187981ee793e9ae400bd5.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-ea326097-27d7-4051-be0d-2defc8141792'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-ea326097-27d7-4051-be0d-2defc8141792'
# 2023-03-25 11:25:30,770 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 11:25:39,082 - distributed.worker - ERROR - Exception during execution of task lambda-46d32e50eb28b0d8b6c6e7f665849290.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-3c2ed316-6396-45ee-b659-cf09899e1acb'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-3c2ed316-6396-45ee-b659-cf09899e1acb'
# 2023-03-25 11:25:40,879 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# UserWarning: Distributing <class 'dict'> object. This may take some time.

# %%
#| label: fig-rate_log-flubot-exp-1-3
#| fig-cap: $\rho(a)$ plot for all instances (B2 period)
#| fig-subcap: 
#|   - "sensitivity 0.8"
#|   - "sensitivity 0.9"

import matplotlib.pyplot as plt

for sensitivity, value in data.items():
    print(sensitivity)
    fig, axs = plt.subplots(ncols=1, figsize=(12, 4))
    df_calcs = value["df_calc"]
    for host in local_ips:
        df_calc_host = df_calcs[df_calcs["index"] == host].set_index("ts")
        df_calc_host["rate_log"].plot(label=f'{host}', ax=axs)

    plt.ylim(ymin=0)
    plt.title(f"Sensitivity: {sensitivity}, threshold: {value['threshold']}")
    plt.legend()
    plt.show()
# Out:
# 2023-03-25 11:25:50,610 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 0.8
# 2023-03-25 11:25:52,472 - distributed.worker - ERROR - Exception during execution of task lambda-8692ec85d9855b09998f6eb2622ce31b.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'apply_list_of_funcs-1c8b6578-4d89-49a0-9f99-6e2a56a292e2'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'apply_list_of_funcs-1c8b6578-4d89-49a0-9f99-6e2a56a292e2'
# 2023-03-25 11:25:52,561 - distributed.worker - ERROR - Exception during execution of task lambda-8f215ddc33b0f848f62feadde7bb5ad0.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'apply_list_of_funcs-ab62fb8c-4450-4c4f-bc9c-4fe265f649a9'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'apply_list_of_funcs-ab62fb8c-4450-4c4f-bc9c-4fe265f649a9'
# 2023-03-25 11:25:53,931 - distributed.worker - ERROR - Exception during execution of task lambda-28bfe1abafc922a58956281a87a16f34.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'apply_list_of_funcs-