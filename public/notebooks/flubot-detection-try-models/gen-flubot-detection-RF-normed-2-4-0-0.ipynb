# %% [markdown]
# ---
# execute:
#   echo: true
#   enabled: false
#   output: true
#   warning: false
# format:
#     html:
#         code-fold: false
# ---

# %% [markdown]
# # Detect malware (RF normed-2-4-0-0)

# %% [markdown]
# The model deployment is done in two stages: I. tune the model, II. turn on the malware detection (on the data collected in B1 and B2 periods respectively, described in the timeline @fig-timeline)
#
# ![Timeline](../../imgs/timeline.png)
#
# ### Stage I: Model tuning
#
# On this state we fit the scaler on the data collected in B1 period, to be used later on the second stage

# %%
#| echo: false
#| output: false
basepath = "/home/u1/"

# %%
#| echo: false
#| output: false
import os
os.environ["MODIN_ENGINE"] = "dask"
import modin.pandas as pd
import numpy as np

pd.set_option("display.max_columns", None)

# %%
from detect_common import *

# %%
#| output: false
p1version = "v6"
p2version = "v7"
p3version = "v5"

# %%
model = 'RF'
normed = True
skips_and_weights = [2,4,0,0]

# %%
# Parameters
model = "RF"
normed = True
skips_and_weights = [2, 4, 0, 0]

# %%
import dateutil.parser

df_b1 = pd.read_feather("cached/v5_1.ft")
# Out:
# UserWarning: Dask execution environment not yet initialized. Initializing...
# To remove this warning, run the following python code before doing dataframe operations:
#
#     from distributed import Client
#
#     client = Client()
#
# UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 44313 instead

# %%
path_doh_ips_androids = basepath + "datasets/flubot20230323/data/v5_benign_doh_ips.csv"
path_doh_ips_general = "doh_resolver_ip.csv"
full_list = get_doh_ips(path_doh_ips_androids) + get_doh_ips(path_doh_ips_general)

cp = CacheableProcessing(100, 100, full_list)
df_b1_p = cp.process(df_b1, f"cached/v5_1.p3.{p3version}.cp.ft")
# Out:
# UserWarning: `Series.tolist` is not currently supported by PandasOnDask, defaulting to pandas implementation.
# Please refer to https://modin.readthedocs.io/en/stable/supported_apis/defaulting_to_pandas.html for explanation.
# UserWarning: `Series.tolist` is not currently supported by PandasOnDask, defaulting to pandas implementation.
# UserWarning: Defaulting to pandas implementation.
# Reason: `lines` argument not supported
# FutureWarning: the 'numpy' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'numpy'

# %%
from joblib import dump, load

name = (
    ('normed-' if normed else 'unnormed-') + 
    '-'.join(str(p) for p in skips_and_weights)
)

clf = load(f'models/{model}-mix-1-p-{name}.p1.{p1version}.p2.{p2version}.joblib')

# %%
pp_b1 = PreProcessing(normed, *skips_and_weights)

df_b1_pp = pp_b1.process(
    df_b1_p,
    f"cached/p3.{p3version}.pp.{model}-{name}.saved", 
    fit_new_scaler=True
)
# Out:
# UserWarning: Defaulting to pandas implementation.
# Reason: `lines` argument not supported
# FutureWarning: the 'numpy' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'numpy'
# UserWarning: Defaulting to pandas implementation.
# Reason: `lines` argument not supported
# FutureWarning: the 'numpy' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'numpy'
# UserWarning: Defaulting to pandas implementation.
# Reason: `lines` argument not supported
# FutureWarning: the 'numpy' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'numpy'

# %%
pp_b1.store_scaler(
    f"cached/p3.{p3version}.pp.{model}-{name}.scaler"
)

# %% [markdown]
# ### Stage II: Malware detection
#
# On this state we turn on the malware detection, provisioning the model with the scaler trained before. For malware detection we use the data trained in B2 period.

# %%
df_b2 = pd.read_feather("cached/v5_2.ft")

# %%
cp = CacheableProcessing(100, 100, full_list)
df_b2_p = cp.process(df_b2, f"cached/v5_2.p3.{p3version}.cp.ft")
# Out:
# UserWarning: Defaulting to pandas implementation.
# Reason: `lines` argument not supported
# FutureWarning: the 'numpy' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'numpy'

# %%
pp_b2 = PreProcessing(normed, *skips_and_weights)
pp_b2.load_scaler(
    f"cached/p3.{p3version}.pp.{model}-{name}.scaler"
)
df_b2_pp, df_b2_pp_features, df_b2_pp_labels = pp_b2.process(
    df_b2_p,
    f"cached/b2.p3.{p3version}.pp.{model}-{name}.saved", 
    fit_new_scaler=False  # use scaler trained in B1
)
# Out:
# UserWarning: Defaulting to pandas implementation.
# Reason: `lines` argument not supported
# FutureWarning: the 'numpy' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'numpy'
# UserWarning: Defaulting to pandas implementation.
# Reason: `lines` argument not supported
# FutureWarning: the 'numpy' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'numpy'
# UserWarning: Defaulting to pandas implementation.
# Reason: `lines` argument not supported
# FutureWarning: the 'numpy' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'numpy'

# %%
def predict(pp, clf, threshold, df_pp, df_orig):
    """
    pp: PreProcessing object
    clf: classifier
    threshold: >=threshold for positive (DoH) class
    df_pp: preprocessed dataframe
    df_orig: unprocessed dataframe
    """
    df_pp2 = df_pp.copy()

    df_pp2["IsDoHPredicted"] = (clf.predict_proba(df_pp2[pp.feature_fields])[:,1] >= threshold).astype(bool)

    df_orig2 = df_orig.copy()
    # fill predicted to the original dataframe
    df_orig2["IsDoHPredicted"] = df_pp2["IsDoHPredicted"]
    # non-443 rows will be NaN, replace with False
    df_orig2["IsDoHPredicted"] = df_orig2["IsDoHPredicted"].fillna(False)

    return df_orig2

# %%
results_df = pd.read_feather(f"cached/robustness.balanced_mix-results.p3.{p3version}.ft")
results_df["skips_and_weights"] = results_df["skips_and_weights"].apply(str)
model, normed, skips_and_weights_str, auc, fprs, tprs, thresholds = results_df[
    (results_df["model"] == model) & (results_df["normed"] == normed) & (results_df["skips_and_weights"] == str(np.array(skips_and_weights)))
].iloc[0]

# %%
data = {}
for sensitivity in [0.8, 0.9]:
    threshold = [threshold for tpr, threshold in zip(tprs, thresholds) if tpr >= sensitivity][0]
    df_pred = predict(pp_b2, clf, threshold, df_b2_pp, df_b2)
    data[sensitivity] = {
        'df': df_pred,  # dataframe with predicted values,
        'threshold': threshold,
    }

# %%
def calc(df_n):
    def rate(df_h):
        dns_packets = df_h[df_h["IsDoHPredicted"] == True]["uint32 PACKETS"].sum()  # outgoing packets
        non_dns_ips = set(df_h[df_h["IsDoHPredicted"] == False]["ipaddr SRC_IP"].unique()).union(
            set(df_h[df_h["IsDoHPredicted"] == False]["ipaddr DST_IP"].unique()))
        rate = float(dns_packets) / (1.0 + len(non_dns_ips))
        return {"dns_packets": dns_packets, "non_dns": len(non_dns_ips), "rate": rate, "rate_log": np.log(rate)}

    return pd.DataFrame({ ip: rate(grp) for ip, grp in df_n.groupby(["ipaddr SRC_IP"]) }).T.reset_index()

# %% [markdown]
# #### Calculate ratio on the whole dataset

# %%
for sensitivity, value in data.items():
    print(sensitivity)
    df_pred = value["df"]
    local_df = df_pred[df_pred["ipaddr SRC_IP"].str.startswith("192.168")]
    display(calc(local_df))
# Out:
# 0.8
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# RuntimeWarning: divide by zero encountered in log
# 2023-03-25 10:13:23,707 - distributed.worker - ERROR - Exception during execution of task lambda-7ff9853f6580fd1cbd48c7aa285672fb.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-ed7b4918-a40f-40ef-b20a-cf1d7f9f4548'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-ed7b4918-a40f-40ef-b20a-cf1d7f9f4548'
# RuntimeWarning: divide by zero encountered in log
# UserWarning: Distributing <class 'dict'> object. This may take some time.
#            index  dns_packets  non_dns          rate  rate_log
# 0    192.168.1.1          0.0      2.0      0.000000      -inf
# 1  192.168.2.149     230029.0   4508.0     51.015525  3.932130
# 2  192.168.2.217     334045.0     17.0  18558.055556  9.828659
# 3  192.168.2.249     140504.0   3575.0     39.290828  3.670991
# 4   192.168.2.42          0.0      5.0      0.000000      -inf
# 0.9
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# RuntimeWarning: divide by zero encountered in log
# 2023-03-25 10:14:13,981 - distributed.worker - ERROR - Exception during execution of task lambda-1742f7c46cf42d0e9cde87b8fa2b28e6.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'apply_func-573c43ee-476c-409b-afc3-c7ce0cee1c0b'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'apply_func-573c43ee-476c-409b-afc3-c7ce0cee1c0b'
# 2023-03-25 10:14:46,080 - distributed.worker - ERROR - Exception during execution of task lambda-9e82872ccdc128c7d5ac8357caa27005.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'apply_func-7efb45bb-1dd7-439b-ad44-232f879f810b'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'apply_func-7efb45bb-1dd7-439b-ad44-232f879f810b'
# 2023-03-25 10:15:30,330 - distributed.worker - ERROR - Exception during execution of task lambda-2e5a64a58f768914202940c676bab1ca.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'apply_func-edb39aa8-54f2-480c-a6e8-3fe15bc185f9'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'apply_func-edb39aa8-54f2-480c-a6e8-3fe15bc185f9'
# RuntimeWarning: divide by zero encountered in log
# UserWarning: Distributing <class 'dict'> object. This may take some time.
#            index  dns_packets  non_dns          rate   rate_log
# 0    192.168.1.1          0.0      2.0      0.000000       -inf
# 1  192.168.2.149     271287.0   4303.0     63.031366   4.143632
# 2  192.168.2.217     609350.0     17.0  33852.777778  10.429776
# 3  192.168.2.249     184519.0   3414.0     54.031918   3.989575
# 4   192.168.2.42          0.0      5.0      0.000000       -inf

# %% [markdown]
# #### Split into time windows

# %%
min_ts = df_b2["time TIME_FIRST"].apply(dateutil.parser.parse).min()
min_ts
# Out:
# Timestamp('2023-03-23 14:50:04.316951')

# %%
local_ips = df_b2[df_b2["ipaddr SRC_IP"].str.startswith("192.168")]["ipaddr SRC_IP"].unique().tolist()
local_ips
# Out:
# ['192.168.2.249',
#  '192.168.2.149',
#  '192.168.2.42',
#  '192.168.2.217',
#  '192.168.1.1']

# %%
f = '3min'

for sensitivity, value in data.items():
    print(sensitivity)

    df_pred = value["df"]
    local_df = df_pred[df_pred["ipaddr SRC_IP"].str.startswith("192.168")].copy()
    local_df["time TIME_FIRST"] = local_df["time TIME_FIRST"].apply(dateutil.parser.parse)
    
    calc_ips = {}

    a1_t = local_df.set_index(["time TIME_FIRST"])

    df_resample = a1_t.groupby(pd.Grouper(freq=f, origin=min_ts)).first()
    times = df_resample.index.tolist()
    ranges = list(zip(times, times[1:]))

    df_calcs = []
    for ran in ranges:
        df_ran = a1_t[(a1_t.index > ran[0]) & (a1_t.index < ran[1])]
        df_calc = calc(df_ran)
        df_calc["ts"] = ran[0]
        df_calcs.append(df_calc)

    value["df_calc"] = pd.concat(df_calcs).reset_index(drop=True)
# Out:
# 0.8
# UserWarning: `DataFrame.groupby_on_multiple_columns` is not currently supported by PandasOnDask, defaulting to pandas implementation.
# FutureWarning: The `squeeze` parameter is deprecated and will be removed in a future version.
# UserWarning: Distributing <class 'pandas.core.frame.DataFrame'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 10:16:08,435 - distributed.worker - ERROR - Exception during execution of task lambda-cf651aa3d1f7cc01a0a97550906710ce.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-12368753-9c0a-4c7d-bf54-4f83aaa493ac'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-12368753-9c0a-4c7d-bf54-4f83aaa493ac'
# RuntimeWarning: divide by zero encountered in log
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 10:16:19,404 - distributed.worker - ERROR - Exception during execution of task lambda-a12890ea034abc8fd2c381d9a65a555a.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-608b3f1a-9c4a-4e85-90bc-a3af0528c461'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-608b3f1a-9c4a-4e85-90bc-a3af0528c461'
# 2023-03-25 10:16:21,737 - distributed.worker - ERROR - Exception during execution of task lambda-1a7d25be406f747feb5eff3122920958.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-2243d8af-a27e-419f-8075-27e530e4b908'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-2243d8af-a27e-419f-8075-27e530e4b908'
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 10:16:26,574 - distributed.worker - ERROR - Exception during execution of task lambda-d0581cb75164d9a49bae40c0c45c3de4.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-9fa663f7-49fc-4406-a953-0eed4a4a9a4a'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-9fa663f7-49fc-4406-a953-0eed4a4a9a4a'
# RuntimeWarning: divide by zero encountered in log
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 10:16:36,606 - distributed.worker - ERROR - Exception during execution of task lambda-97c8c60508107b4e7c8045dfe03fab90.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-3965f27d-44e9-439f-a03a-b9c13ab1ae64'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-3965f27d-44e9-439f-a03a-b9c13ab1ae64'
# 2023-03-25 10:16:39,015 - distributed.worker - ERROR - Exception during execution of task lambda-520f9cc5f58fadcd2efc917f129b8f08.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-611b20ae-2001-408d-9291-2ef31decac25'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func

# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-e0dc99d4-13de-4ebd-b917-31400e241381'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-e0dc99d4-13de-4ebd-b917-31400e241381'
# 2023-03-25 10:28:25,481 - distributed.worker - ERROR - Exception during execution of task lambda-2b8e1873d692b219a38c92cf742ff15e.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-676decec-1899-49e9-b040-9704f1844309'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-676decec-1899-49e9-b040-9704f1844309'
# RuntimeWarning: divide by zero encountered in log
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 10:28:29,550 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 10:28:39,822 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2023-03-25 10:28:43,885 - distributed.worker - ERROR - Exception during execution of task lambda-a1219fda9234198e8c3ea169af034291.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-30ee9237-c83b-443b-a8f1-b586a51cc249'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-30ee9237-c83b-443b-a8f1-b586a51cc249'
# 2023-03-25 10:28:49,835 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# UserWarning: Distributing <class 'dict'> object. This may take some time.

# %%
#| label: fig-rate_log-flubot-exp-1-4
#| fig-cap: $\rho(a)$ plot for all instances (B2 period)
#| fig-subcap: 
#|   - "sensitivity 0.8"
#|   - "sensitivity 0.9"

import matplotlib.pyplot as plt

for sensitivity, value in data.items():
    print(sensitivity)
    fig, axs = plt.subplots(ncols=1, figsize=(12, 4))
    df_calcs = value["df_calc"]
    for host in local_ips:
        df_calc_host = df_calcs[df_calcs["index"] == host].set_index("ts")
        df_calc_host["rate_log"].plot(label=f'{host}', ax=axs)

    plt.ylim(ymin=0)
    plt.title(f"Sensitivity: {sensitivity}, threshold: {value['threshold']}")
    plt.legend()
    plt.show()
# Out:
# 0.8
# 2023-03-25 10:28:53,107 - distributed.worker - ERROR - Exception during execution of task lambda-d96e4887c9068783ebe4cde3b97e56b4.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'apply_list_of_funcs-9925ad02-943a-4534-96eb-3f63842a7db0'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'apply_list_of_funcs-9925ad02-943a-4534-96eb-3f63842a7db0'
# 2023-03-25 10:28:53,372 - distributed.worker - ERROR - Exception during execution of task lambda-1209ad4e25b563df39b904c7f28bc60d.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'apply_list_of_funcs-d9f5c8ac-3cb9-4953-bb74-8c97095e41b8'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'apply_list_of_funcs-d9f5c8ac-3cb9-4953-bb74-8c97095e41b8'
# 2023-03-25 10:28:53,674 - distributed.worker - ERROR - Exception during execution of task lambda-42238336118ce2c463315f728794306a.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'apply_list_of_funcs-b2698917-bc83-40bb-90be-ae9e8a62ce37'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'apply_list_of_funcs-b2698917-bc83-40bb-90be-ae9e8a62ce37'
# 2023-03-25 10:28:55,051 - distributed.worker - ERROR - Exception during execution of task lambda-4451e23d881510439e79dc282cc9e9c7.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'apply_list_of_funcs-c564c924-6b73-4e22-ad57-7ed3c6968599'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'apply_list_of_funcs-c564c924-6b73-4e22-ad57-7ed3c6968599'
# 2023-03-25 10:28:55,134 - distributed.worker - ERROR - Exception during execution of task lambda-3e98a18ed82f1c5d13fe1926b3758006.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'apply_list_of_funcs-994071ad-5592-4c20-8a8d-9601cf66e3b7'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'apply_list_of_funcs-994071ad-5592-4c20-8a8d-9601cf66e3b7'
# 2023-03-25 10:28:55,430 - distributed.worker - ERROR - Exception during execution of task lambda-4dd92f876b4872cab71c3464501b7be7.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'apply_list_of_funcs-6a1a97a0-c919-4a91-a3fa-c8418ecc87f5'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'apply_list_of_funcs

#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'apply_list_of_funcs-24d860fb-8fe6-4863-b5ba-7cdfb7b1c58f'
# 2023-03-25 10:29:06,360 - distributed.worker - ERROR - Exception during execution of task lambda-b5b4412483117f2896a401142f26d402.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'apply_list_of_funcs-a7166424-9200-4457-86ce-c48d4a8f7cd4'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'apply_list_of_funcs-a7166424-9200-4457-86ce-c48d4a8f7cd4'
# 2023-03-25 10:29:06,417 - distributed.worker - ERROR - Exception during execution of task lambda-b0bfbd21f2d2a907671f835a11020b22.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'apply_list_of_funcs-7877f7c4-b4d4-4b93-902c-2d39854da250'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'apply_list_of_funcs-7877f7c4-b4d4-4b93-902c-2d39854da250'
# 2023-03-25 10:29:07,915 - distributed.worker - ERROR - Exception during execution of task lambda-64b18a53d8944d78c29d5d4b7cba783f.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'apply_list_of_funcs-227a513c-69cd-42e5-9a8c-8a8faa1cb0d1'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'apply_list_of_funcs-227a513c-69cd-42e5-9a8c-8a8faa1cb0d1'
# 2023-03-25 10:29:09,371 - distributed.worker - ERROR - Exception during execution of task lambda-9b4d559858ae4eb2e4304b25ee38d79e.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'apply_list_of_funcs-519eda0a-73db-4317-ba1b-92c9668654d5'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'apply_list_of_funcs-519eda0a-73db-4317-ba1b-92c9668654d5'
# 2023-03-25 10:29:09,574 - distributed.worker - ERROR - Exception during execution of task lambda-e82dd5d3bfd0c415b8af4f53c025a9be.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'apply_list_of_funcs-1c2b42b6-6a10-4925-99c8-d84801d1d9fe'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'apply_list_of_funcs-1c2b42b6-6a10-4925-99c8-d84801d1d9fe'
# 2023-03-25 10:29:09,840 - distributed.worker - ERROR - Exception during execution of task lambda-04962468599759d269b92447b2aa8994.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'apply_list_of_funcs-5665fe0d-668d-4ff6-a468-07a6d03fc8d2'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'apply_list_of_funcs-5665fe0d-668d-4ff6-a468-07a6d03fc8d2'
# 2023-03-25 10:29:09,981 - distributed.worker - ERROR - Exception during execution of task lambda-bb9ee465747a807e268f2fb3ff86fd88.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'apply_list_of_funcs-33193363-aa55-44d8-825f-c71c7a546799'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'apply_list_of_funcs-33193363-aa55-44d8-825f-c71c7a546799'
# 2023-03-25 10:29:10,086 - distributed.worker - ERROR - Exception during execution of task lambda-4532f7f047a83f4018d40170279ed67a.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'apply_list_of_funcs-f15a7d2a-c438-490d-8232-950fdd708d55'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'apply_list_of_funcs-f15a7d2a-c438-490d-8232-950fdd708d55'
# 2023-03-25 10:29:11,158 - distributed.worker - ERROR - Exception during execution of task lambda-8d4f70aae9f235cd9d782ec99e49c84a.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'apply_list_of_funcs-b4aecf19-411f-4d4c-823c-68d9c3b47f88'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'apply_list_of_funcs-b4aecf19-411f-4d4c-823c-68d9c3b47f88'
# 2023-03-25 10:29:11,318 - distributed.worker - ERROR - Exception during execution of task lambda-66f6ab9be66d3362e9aca79473912bae.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'apply_list_of_funcs-a7171e48-b395-4bce-bd85-ffc8a9f62110'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'apply_list_of_funcs-a7171e48-b395-4bce-bd85-ffc8a9f62110'
# 2023-03-25 10:29:11,795 - distributed.worker - ERROR - Exception during execution of task lambda-38333dc12b2a55d43fd8a9df857492f3.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'apply_list_of_funcs-d92903f8-52f1-42fb-a417-fa336d4b87d3'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'apply_list_of_funcs-d92903f8-52f1-42fb-a417-fa336d4b87d3'
