# %% [markdown]
# ---
# execute:
#   echo: true
#   enabled: false
#   output: true
#   warning: false
# format:
#     html:
#         code-fold: false
# ---

# %% [markdown]
# # Detect malware (RF unnormed-0-0-0-0)

# %% [markdown]
# The model deployment is done in two stages: I. tune the model, II. turn on the malware detection (on the data collected in B1 and B2 periods respectively, described in the timeline @fig-timeline)
#
# ![Timeline](../../imgs/timeline.png)
#
# ### Stage I: Model tuning
#
# On this state we fit the scaler on the data collected in B1 period, to be used later on the second stage

# %%
#| echo: false
#| output: false
basepath = "/home/u1/"

# %%
#| echo: false
#| output: false
import os
os.environ["MODIN_ENGINE"] = "dask"
import modin.pandas as pd
import numpy as np

pd.set_option("display.max_columns", None)

# %%
from detect_common import *

# %%
#| output: false
p1version = "v6"
p2version = "v7"
p3version = "v5"

# %%
model = 'RF'
normed = True
skips_and_weights = [2,4,0,0]

# %%
# Parameters
model = "RF"
normed = False
skips_and_weights = [0, 0, 0, 0]

# %%
import dateutil.parser

df_b1 = pd.read_feather("cached/v5_1.ft")
# Out:
# UserWarning: Dask execution environment not yet initialized. Initializing...
# To remove this warning, run the following python code before doing dataframe operations:
#
#     from distributed import Client
#
#     client = Client()
#
# UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 39363 instead

# %%
path_doh_ips_androids = basepath + "datasets/flubot20230323/data/v5_benign_doh_ips.csv"
path_doh_ips_general = "doh_resolver_ip.csv"
full_list = get_doh_ips(path_doh_ips_androids) + get_doh_ips(path_doh_ips_general)

cp = CacheableProcessing(100, 100, full_list)
df_b1_p = cp.process(df_b1, f"cached/v5_1.p3.{p3version}.cp.ft")
# Out:
# UserWarning: `Series.tolist` is not currently supported by PandasOnDask, defaulting to pandas implementation.
# Please refer to https://modin.readthedocs.io/en/stable/supported_apis/defaulting_to_pandas.html for explanation.
# UserWarning: `Series.tolist` is not currently supported by PandasOnDask, defaulting to pandas implementation.
# UserWarning: Defaulting to pandas implementation.
# Reason: `lines` argument not supported
# FutureWarning: the 'numpy' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'numpy'

# %%
from joblib import dump, load

name = (
    ('normed-' if normed else 'unnormed-') + 
    '-'.join(str(p) for p in skips_and_weights)
)

clf = load(f'models/{model}-mix-1-p-{name}.p1.{p1version}.p2.{p2version}.joblib')

# %%
pp_b1 = PreProcessing(normed, *skips_and_weights)

df_b1_pp = pp_b1.process(
    df_b1_p,
    f"cached/p3.{p3version}.pp.{model}-{name}.saved", 
    fit_new_scaler=True
)
# Out:
# UserWarning: Defaulting to pandas implementation.
# Reason: `lines` argument not supported
# FutureWarning: the 'numpy' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'numpy'
# UserWarning: Defaulting to pandas implementation.
# Reason: `lines` argument not supported
# FutureWarning: the 'numpy' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'numpy'
# UserWarning: Defaulting to pandas implementation.
# Reason: `lines` argument not supported
# FutureWarning: the 'numpy' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'numpy'
# 2023-03-25 09:51:45,190 - distributed.worker - WARNING - Could not find data: {'function-ad982395bb6e4654bade21e735487976': ['tcp://127.0.0.1:46405', 'tcp://127.0.0.1:34977', 'tcp://127.0.0.1:43095']} on workers: [] (who_has: {'function-ad982395bb6e4654bade21e735487976': ['tcp://127.0.0.1:46405', 'tcp://127.0.0.1:34977', 'tcp://127.0.0.1:43095']})
# 2023-03-25 09:51:45,192 - distributed.scheduler - WARNING - Worker tcp://127.0.0.1:39211 failed to acquire keys: {'function-ad982395bb6e4654bade21e735487976': ('tcp://127.0.0.1:46405', 'tcp://127.0.0.1:34977', 'tcp://127.0.0.1:43095')}

# %%
pp_b1.store_scaler(
    f"cached/p3.{p3version}.pp.{model}-{name}.scaler"
)

# %% [markdown]
# ### Stage II: Malware detection
#
# On this state we turn on the malware detection, provisioning the model with the scaler trained before. For malware detection we use the data trained in B2 period.

# %%
df_b2 = pd.read_feather("cached/v5_2.ft")

# %%
cp = CacheableProcessing(100, 100, full_list)
df_b2_p = cp.process(df_b2, f"cached/v5_2.p3.{p3version}.cp.ft")
# Out:
# UserWarning: Defaulting to pandas implementation.
# Reason: `lines` argument not supported
# FutureWarning: the 'numpy' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'numpy'

# %%
pp_b2 = PreProcessing(normed, *skips_and_weights)
pp_b2.load_scaler(
    f"cached/p3.{p3version}.pp.{model}-{name}.scaler"
)
df_b2_pp, df_b2_pp_features, df_b2_pp_labels = pp_b2.process(
    df_b2_p,
    f"cached/b2.p3.{p3version}.pp.{model}-{name}.saved", 
    fit_new_scaler=False  # use scaler trained in B1
)
# Out:
# UserWarning: Defaulting to pandas implementation.
# Reason: `lines` argument not supported
# FutureWarning: the 'numpy' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'numpy'
# UserWarning: Defaulting to pandas implementation.
# Reason: `lines` argument not supported
# FutureWarning: the 'numpy' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'numpy'
# UserWarning: Defaulting to pandas implementation.
# Reason: `lines` argument not supported
# FutureWarning: the 'numpy' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'numpy'

# %%
def predict(pp, clf, threshold, df_pp, df_orig):
    """
    pp: PreProcessing object
    clf: classifier
    threshold: >=threshold for positive (DoH) class
    df_pp: preprocessed dataframe
    df_orig: unprocessed dataframe
    """
    df_pp2 = df_pp.copy()

    df_pp2["IsDoHPredicted"] = (clf.predict_proba(df_pp2[pp.feature_fields])[:,1] >= threshold).astype(bool)

    df_orig2 = df_orig.copy()
    # fill predicted to the original dataframe
    df_orig2["IsDoHPredicted"] = df_pp2["IsDoHPredicted"]
    # non-443 rows will be NaN, replace with False
    df_orig2["IsDoHPredicted"] = df_orig2["IsDoHPredicted"].fillna(False)

    return df_orig2

# %%
results_df = pd.read_feather(f"cached/robustness.balanced_mix-results.p3.{p3version}.ft")
results_df["skips_and_weights"] = results_df["skips_and_weights"].apply(str)
model, normed, skips_and_weights_str, auc, fprs, tprs, thresholds = results_df[
    (results_df["model"] == model) & (results_df["normed"] == normed) & (results_df["skips_and_weights"] == str(np.array(skips_and_weights)))
].iloc[0]

# %%
data = {}
for sensitivity in [0.8, 0.9]:
    threshold = [threshold for tpr, threshold in zip(tprs, thresholds) if tpr >= sensitivity][0]
    df_pred = predict(pp_b2, clf, threshold, df_b2_pp, df_b2)
    data[sensitivity] = {
        'df': df_pred,  # dataframe with predicted values,
        'threshold': threshold,
    }

# %%
def calc(df_n):
    def rate(df_h):
        dns_packets = df_h[df_h["IsDoHPredicted"] == True]["uint32 PACKETS"].sum()  # outgoing packets
        non_dns_ips = set(df_h[df_h["IsDoHPredicted"] == False]["ipaddr SRC_IP"].unique()).union(
            set(df_h[df_h["IsDoHPredicted"] == False]["ipaddr DST_IP"].unique()))
        rate = float(dns_packets) / (1.0 + len(non_dns_ips))
        return {"dns_packets": dns_packets, "non_dns": len(non_dns_ips), "rate": rate, "rate_log": np.log(rate)}

    return pd.DataFrame({ ip: rate(grp) for ip, grp in df_n.groupby(["ipaddr SRC_IP"]) }).T.reset_index()

# %% [markdown]
# #### Calculate ratio on the whole dataset

# %%
for sensitivity, value in data.items():
    print(sensitivity)
    df_pred = value["df"]
    local_df = df_pred[df_pred["ipaddr SRC_IP"].str.startswith("192.168")]
    display(calc(local_df))
# Out:
# 0.8
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# RuntimeWarning: divide by zero encountered in log
# 2023-03-25 09:54:02,612 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2023-03-25 09:54:08,221 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2023-03-25 09:54:10,658 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2023-03-25 09:54:13,230 - distributed.worker - ERROR - Exception during execution of task lambda-ad99f20b621a791b9173f1536a246669.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'apply_func-69990e4d-1f0c-402d-9c32-e355cda89319'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'apply_func-69990e4d-1f0c-402d-9c32-e355cda89319'
# 2023-03-25 09:54:15,393 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2023-03-25 09:54:20,459 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2023-03-25 09:54:23,094 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2023-03-25 09:54:27,696 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2023-03-25 09:54:32,246 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# RuntimeWarning: divide by zero encountered in log
# UserWarning: Distributing <class 'dict'> object. This may take some time.
#            index  dns_packets  non_dns        rate  rate_log
# 0    192.168.1.1          0.0      2.0    0.000000      -inf
# 1  192.168.2.149     127048.0   4905.0   25.896453  3.254106
# 2  192.168.2.217      18589.0     20.0  885.190476  6.785803
# 3  192.168.2.249      39503.0   3850.0   10.257855  2.328044
# 4   192.168.2.42          0.0      5.0    0.000000      -inf
# 0.9
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 09:54:44,365 - distributed.worker - ERROR - Exception during execution of task lambda-1714cfb9dec557508c99998268fca81b.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-b3d02512-afca-41ad-b709-434b4fc0b399'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-b3d02512-afca-41ad-b709-434b4fc0b399'
# RuntimeWarning: divide by zero encountered in log
# 2023-03-25 09:54:55,725 - distributed.worker - ERROR - Exception during execution of task lambda-f84af0fe9b60b840d239e69aa9ca32be.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-42c0bd94-466e-406c-bc38-7b2ae020abb0'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-42c0bd94-466e-406c-bc38-7b2ae020abb0'
# 2023-03-25 09:55:06,521 - distributed.worker - ERROR - Exception during execution of task lambda-c8f76f9a90c5607c7ce13735a728f55a.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'apply_func-36f60ec4-c95f-4161-9dac-ecde6e1b54ae'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'apply_func-36f60ec4-c95f-4161-9dac-ecde6e1b54ae'
# 2023-03-25 09:55:52,071 - distributed.worker - ERROR - Exception during execution of task lambda-d62f3388c5183ae0bf65ca762cdb70fb.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'apply_func-67e65e16-9078-48b5-af5d-1f048c2a88b8'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'apply_func-67e65e16-9078-48b5-af5d-1f048c2a88b8'
# 2023-03-25 09:56:26,231 - distributed.worker - ERROR - Exception during execution of task lambda-14bf37d97f64c3a6138c22a5a3c282d1.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'apply_func-1d7c2726-dd38-4f03-8a3c-e7790b7be80e'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'apply_func-1d7c2726-dd38-4f03-8a3c-e7790b7be80e'
# RuntimeWarning: divide by zero encountered in log
# UserWarning: Distributing <class 'dict'> object. This may take some time.
#            index  dns_packets  non_dns         rate  rate_log
# 0    192.168.1.1          0.0      2.0     0.000000      -inf
# 1  192.168.2.149     167503.0   4797.0    34.911005  3.552802
# 2  192.168.2.217     118691.0     19.0  5934.550000  8.688546
# 3  192.168.2.249      80540.0   3761.0    21.408825  3.063803
# 4   192.168.2.42          0.0      5.0     0.000000      -inf

# %% [markdown]
# #### Split into time windows

# %%
min_ts = df_b2["time TIME_FIRST"].apply(dateutil.parser.parse).min()
min_ts
# Out:
# 2023-03-25 09:56:36,855 - distributed.worker - ERROR - Exception during execution of task lambda-6c8a9db28758de594f240e89f3c490c5.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-b4f1e5db-64cf-499d-826e-6dc172a70ca8'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-b4f1e5db-64cf-499d-826e-6dc172a70ca8'
# Timestamp('2023-03-23 14:50:04.316951')

# %%
local_ips = df_b2[df_b2["ipaddr SRC_IP"].str.startswith("192.168")]["ipaddr SRC_IP"].unique().tolist()
local_ips
# Out:
# 2023-03-25 09:56:47,546 - distributed.worker - ERROR - Exception during execution of task lambda-dfe6d1828938ff3e589008c5ac3054d9.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'apply_func-5d1a793b-5260-4c9b-84b0-b9f1e5a2d939'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'apply_func-5d1a793b-5260-4c9b-84b0-b9f1e5a2d939'
# ['192.168.2.249',
#  '192.168.2.149',
#  '192.168.2.42',
#  '192.168.2.217',
#  '192.168.1.1']

# %%
f = '3min'

for sensitivity, value in data.items():
    print(sensitivity)

    df_pred = value["df"]
    local_df = df_pred[df_pred["ipaddr SRC_IP"].str.startswith("192.168")].copy()
    local_df["time TIME_FIRST"] = local_df["time TIME_FIRST"].apply(dateutil.parser.parse)
    
    calc_ips = {}

    a1_t = local_df.set_index(["time TIME_FIRST"])

    df_resample = a1_t.groupby(pd.Grouper(freq=f, origin=min_ts)).first()
    times = df_resample.index.tolist()
    ranges = list(zip(times, times[1:]))

    df_calcs = []
    for ran in ranges:
        df_ran = a1_t[(a1_t.index > ran[0]) & (a1_t.index < ran[1])]
        df_calc = calc(df_ran)
        df_calc["ts"] = ran[0]
        df_calcs.append(df_calc)

    value["df_calc"] = pd.concat(df_calcs).reset_index(drop=True)
# Out:
# 0.8
# UserWarning: `DataFrame.groupby_on_multiple_columns` is not currently supported by PandasOnDask, defaulting to pandas implementation.
# FutureWarning: The `squeeze` parameter is deprecated and will be removed in a future version.
# UserWarning: Distributing <class 'pandas.core.frame.DataFrame'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# RuntimeWarning: divide by zero encountered in log
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 09:57:19,258 - distributed.worker - ERROR - Exception during execution of task lambda-8e3e43577224ac8ff408bd0456eb911d.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-2a3c25be-1df5-49a0-a059-d299a4bb4644'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-2a3c25be-1df5-49a0-a059-d299a4bb4644'
# 2023-03-25 09:57:22,194 - distributed.worker - ERROR - Exception during execution of task lambda-f45bbb7b85a774d6bb3c51980002d3b4.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-b3b30f69-ab5d-46f1-9b50-f97e2c0e3fe6'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-b3b30f69-ab5d-46f1-9b50-f97e2c0e3fe6'
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 09
- distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2023-03-25 10:01:53,891 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 10:02:01,088 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2023-03-25 10:02:03,765 - distributed.worker - ERROR - Exception during execution of task lambda-50932d509a38179ab37c39e51814c5fb.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-df371c31-91d6-4b64-8846-15f3ed629cf4'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-df371c31-91d6-4b64-8846-15f3ed629cf4'
# 2023-03-25 10:02:08,135 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# RuntimeWarning: divide by zero encountered in log
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 10:02:13,029 - distributed.worker - ERROR - Exception during execution of task lambda-574c338d28230d299895085ea447e8a6.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-b2c041ba-80e8-4718-ad0c-16cbca5a0eab'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-b2c041ba-80e8-4718-ad0c-16cbca5a0eab'
# 2023-03-25 10:02:15,033 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 10:02:22,084 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2023-03-25 10:02:22,543 - distributed.worker - ERROR - Exception during execution of task lambda-8e7725ed54f7b04efe2cf5f06b25a36b.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'apply_func-52cc428e-360d-4aff-9723-98c6c42eb2ae'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'apply_func-52cc428e-360d-4aff-9723-98c6c42eb2ae'
# 2023-03-25 10:02:29,069 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 10:02:36,200 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 10:02:43,053 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2023-03-25 10:02:47,032 - distributed.worker - ERROR - Exception during execution of task lambda-b24b5bb9503cf9104da3a03d4b9282f6.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-c8b9954f-0599-42c8-b525-b722e395e6ec'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-c8b9954f-0599-42c8-b525-b722e395e6ec'
# ...
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-efa45a2a-cbff-439d-b81c-3dac6a278840'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-efa45a2a-cbff-439d-b81c-3dac6a278840'
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 10:07:22,299 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 10:07:29,094 - distributed.worker - ERROR - Exception during execution of task lambda-2f3896f07491771605ca3beb3a785769.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-e47fd81f-2296-45ac-8727-fa7fd916b46c'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-e47fd81f-2296-45ac-8727-fa7fd916b46c'
# 2023-03-25 10:07:31,618 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2023-03-25 10:07:33,118 - distributed.worker - WARNING - Could not find data: {'function-54ee7c60e82746c7ae442d3d7dbf29a9': ['tcp://127.0.0.1:37051', 'tcp://127.0.0.1:41481', 'tcp://127.0.0.1:44163', 'tcp://127.0.0.1:37683', 'tcp://127.0.0.1:35903', 'tcp://127.0.0.1:40341', 'tcp://127.0.0.1:40283', 'tcp://127.0.0.1:46405', 'tcp://127.0.0.1:43753']} on workers: [] (who_has: {'function-54ee7c60e82746c7ae442d3d7dbf29a9': ['tcp://127.0.0.1:37051', 'tcp://127.0.0.1:41481', 'tcp://127.0.0.1:44163', 'tcp://127.0.0.1:37683', 'tcp://127.0.0.1:35903', 'tcp://127.0.0.1:40341', 'tcp://127.0.0.1:40283', 'tcp://127.0.0.1:46405', 'tcp://127.0.0.1:43753']})
# 2023-03-25 10:07:33,119 - distributed.scheduler - WARNING - Worker tcp://127.0.0.1:39173 failed to acquire keys: {'function-54ee7c60e82746c7ae442d3d7dbf29a9': ('tcp://127.0.0.1:37051', 'tcp://127.0.0.1:41481', 'tcp://127.0.0.1:44163', 'tcp://127.0.0.1:37683', 'tcp://127.0.0.1:35903', 'tcp://127.0.0.1:40341', 'tcp://127.0.0.1:40283', 'tcp://127.0.0.1:46405', 'tcp://127.0.0.1:43753')}
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 10:07:40,788 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2023-03-25 10:07:42,007 - distributed.worker - ERROR - Exception during execution of task lambda-b43cbbcacd79e7a9c2171509d5b155a9.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-697f1f5f-59e3-4181-a4c1-96689205f3f8'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-697f1f5f-59e3-4181-a4c1-96689205f3f8'
# 2023-03-25 10:07:49,936 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 10:07:59,765 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 10:08:09,480 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2023-03-25 10:08:14,798 - distributed.worker - ERROR - Exception during execution of task lambda-a2601582284fbf9fcce494f6c4ab181a.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'apply_func-48776883-66f4-430d-8bb7-a0d806b20ba1'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'apply_func-48776883-66f4-430d-8bb7-a0d806b20ba1'
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 10:08:19,511 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2023-03-25 10:08:29,491 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 10:08:39,269 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# RuntimeWarning: divide by zero encountered in log
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 10:08:49,013 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 10:08:59,158 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2023-03-25 10:09:01,733 - distributed.worker - ERROR - Exception during execution of task lambda-7eb6e5d163ae6444821be0b4c8abb067.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-226f2276-db9a-42ed-83e1-a0b427e7c0f1'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-226f2276-db9a-42ed-83e1-a0b427e7c0f1'
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 10:09:05,332 - distributed.worker - ERROR - Exception during execution of task lambda-5a6b032380d3f7337c1006ad861d0e6e.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-a153b8e9-edf1-46c2-8caf-5118a87fb6d1'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-a153b8e9-edf1-46c2-8caf-5118a87fb6d1'
# 2023-03-25 10:09:09,506 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2023-03-25 10:09:13,702 - distributed.worker - ERROR - Exception during execution of task lambda-5986671dbb6b8d862bd735ea733d755e.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-2a38e6f1-bd0c-4c8d-8657-10a8a19c78b1'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-2a38e6f1-bd0c-4c8d-8657-10a8a19c78b1'
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 10:09:19,929 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2023-03-25 10:09:29,074 - distributed.worker - ERROR - Exception during execution of task lambda-a1d0444afe749e0b54d4fc1130ac1fc6.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-157938d6-0699-4378-8e9e-a5c21168cc5b'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-157938d6-0699-4378-8e9e-a5c21168cc5b'
# 2023-03-25 10:09:30,294 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# RuntimeWarning: divide by zero encountered in log
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 10:09:40,905 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 10:09:47,593 - distributed.worker - ERROR - Exception during execution of task lambda-8c11016f9b19de27bdb0d62a683ffbe4.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-0d803b83-dc74-4e19-afd4-0967ad22238b'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-0d803b83-dc74-4e19-afd4-0967ad22238b'
# 2023-03-25 10:09:50,842 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# UserWarning: Distributing <class 'dict'> object. This may take some time.

# %%
#| label: fig-rate_log-flubot-exp-1-1
#| fig-cap: $\rho(a)$ plot for all instances (B2 period)
#| fig-subcap: 
#|   - "sensitivity 0.8"
#|   - "sensitivity 0.9"

import matplotlib.pyplot as plt

for sensitivity, value in data.items():
    print(sensitivity)
    fig, axs = plt.subplots(ncols=1, figsize=(12, 4))
    df_calcs = value["df_calc"]
    for host in local_ips:
        df_calc_host = df_calcs[df_calcs["index"] == host].set_index("ts")
        df_calc_host["rate_log"].plot(label=f'{host}', ax=axs)

    plt.ylim(ymin=0)
    plt.title(f"Sensitivity: {sensitivity}, threshold: {value['threshold']}")
    plt.legend()
    plt.show()
# Out:
# 0.8
# 2023-03-25 10:09:56,608 - distributed.worker - ERROR - Exception during execution of task lambda-b96113e0a80b27ad553327dc39cb908c.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'apply_list_of_funcs-59fd4bc3-64ec-4a17-ba10-74509057c18b'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'apply_list_of_funcs-59fd4bc3-64ec-4a17-ba10-74509057c18b'
# 2023-03-25 10:09:56,631 - distributed.worker - ERROR - Exception during execution of task lambda-d02ea3378f866a981a635e58b3a96801.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'apply_list_of_funcs-e624094f-af3b-4fdb-b606-b5a29b97c3e1'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'apply_list_of_funcs-e624094f-af3b-4fdb-b606-b5a29b97c3e1'
# 2023-03-25 10:10:00,969 - distributed.worker - ERROR - Exception during execution of task lambda-f34f6879b42ceba9c34c1fc16dfbdf52.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'apply_list_of_funcs-1f9e90b2-afb0-4d99-bb63-ecf43aa87eef'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'apply_list_of_funcs-1f9e90b2-afb0-4d99-bb63-ecf43aa87eef'
# 2023-03-25 10:10:02,907 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2023-03-25 10:10:03,324 - distributed.worker - ERROR - Exception during execution of task lambda-f3df666901dd842d8806a8db19f5d581.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'apply_list_of_funcs-