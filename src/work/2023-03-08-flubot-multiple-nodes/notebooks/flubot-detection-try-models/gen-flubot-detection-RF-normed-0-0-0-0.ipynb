# %% [markdown]
# ---
# execute:
#   echo: true
#   enabled: false
#   output: true
#   warning: false
# format:
#     html:
#         code-fold: false
# ---

# %% [markdown]
# # Detect malware (RF normed-0-0-0-0)

# %% [markdown]
# The model deployment is done in two stages: I. tune the model, II. turn on the malware detection (on the data collected in B1 and B2 periods respectively, described in the timeline @fig-timeline)
#
# ![Timeline](../../imgs/timeline.png)
#
# ### Stage I: Model tuning
#
# On this state we fit the scaler on the data collected in B1 period, to be used later on the second stage

# %%
#| echo: false
#| output: false
basepath = "/home/root/"

# %%
#| echo: false
#| output: false
import os
os.environ["MODIN_ENGINE"] = "dask"
import modin.pandas as pd
import numpy as np

pd.set_option("display.max_columns", None)

# %%
from detect_common import *

# %%
#| output: false
p1version = "v6"
p2version = "v7"
p3version = "v5"

# %%
model = 'RF'
normed = True
skips_and_weights = [2,4,0,0]

# %%
# Parameters
model = "RF"
normed = True
skips_and_weights = [0, 0, 0, 0]

# %%
import dateutil.parser

df_b1 = pd.read_feather("cached/v5_1.ft")
# Out:
# UserWarning: Dask execution environment not yet initialized. Initializing...
# To remove this warning, run the following python code before doing dataframe operations:
#
#     from distributed import Client
#
#     client = Client()
#
# UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 43695 instead

# %%
path_doh_ips_androids = basepath + "datasets/flubot20230323/data/v5_benign_doh_ips.csv"
path_doh_ips_general = "doh_resolver_ip.csv"
full_list = get_doh_ips(path_doh_ips_androids) + get_doh_ips(path_doh_ips_general)

cp = CacheableProcessing(100, 100, full_list)
df_b1_p = cp.process(df_b1, f"cached/v5_1.p3.{p3version}.cp.ft")
# Out:
# UserWarning: `Series.tolist` is not currently supported by PandasOnDask, defaulting to pandas implementation.
# Please refer to https://modin.readthedocs.io/en/stable/supported_apis/defaulting_to_pandas.html for explanation.
# UserWarning: `Series.tolist` is not currently supported by PandasOnDask, defaulting to pandas implementation.
# UserWarning: Defaulting to pandas implementation.
# Reason: `lines` argument not supported
# FutureWarning: the 'numpy' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'numpy'

# %%
from joblib import dump, load

name = (
    ('normed-' if normed else 'unnormed-') + 
    '-'.join(str(p) for p in skips_and_weights)
)

clf = load(f'models/{model}-mix-1-p-{name}.p1.{p1version}.p2.{p2version}.joblib')

# %%
pp_b1 = PreProcessing(normed, *skips_and_weights)

df_b1_pp = pp_b1.process(
    df_b1_p,
    f"cached/p3.{p3version}.pp.{model}-{name}.saved", 
    fit_new_scaler=True
)
# Out:
# UserWarning: Defaulting to pandas implementation.
# Reason: `lines` argument not supported
# FutureWarning: the 'numpy' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'numpy'
# UserWarning: Defaulting to pandas implementation.
# Reason: `lines` argument not supported
# FutureWarning: the 'numpy' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'numpy'
# UserWarning: Defaulting to pandas implementation.
# Reason: `lines` argument not supported
# FutureWarning: the 'numpy' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'numpy'

# %%
pp_b1.store_scaler(
    f"cached/p3.{p3version}.pp.{model}-{name}.scaler"
)

# %% [markdown]
# ### Stage II: Malware detection
#
# On this state we turn on the malware detection, provisioning the model with the scaler trained before. For malware detection we use the data trained in B2 period.

# %%
df_b2 = pd.read_feather("cached/v5_2.ft")

# %%
cp = CacheableProcessing(100, 100, full_list)
df_b2_p = cp.process(df_b2, f"cached/v5_2.p3.{p3version}.cp.ft")
# Out:
# UserWarning: Defaulting to pandas implementation.
# Reason: `lines` argument not supported
# FutureWarning: the 'numpy' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'numpy'

# %%
pp_b2 = PreProcessing(normed, *skips_and_weights)
pp_b2.load_scaler(
    f"cached/p3.{p3version}.pp.{model}-{name}.scaler"
)
df_b2_pp, df_b2_pp_features, df_b2_pp_labels = pp_b2.process(
    df_b2_p,
    f"cached/b2.p3.{p3version}.pp.{model}-{name}.saved", 
    fit_new_scaler=False  # use scaler trained in B1
)
# Out:
# UserWarning: Defaulting to pandas implementation.
# Reason: `lines` argument not supported
# FutureWarning: the 'numpy' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'numpy'
# UserWarning: Defaulting to pandas implementation.
# Reason: `lines` argument not supported
# FutureWarning: the 'numpy' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'numpy'
# UserWarning: Defaulting to pandas implementation.
# Reason: `lines` argument not supported
# FutureWarning: the 'numpy' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'numpy'

# %%
def predict(pp, clf, threshold, df_pp, df_orig):
    """
    pp: PreProcessing object
    clf: classifier
    threshold: >=threshold for positive (DoH) class
    df_pp: preprocessed dataframe
    df_orig: unprocessed dataframe
    """
    df_pp2 = df_pp.copy()

    df_pp2["IsDoHPredicted"] = (clf.predict_proba(df_pp2[pp.feature_fields])[:,1] >= threshold).astype(bool)

    df_orig2 = df_orig.copy()
    # fill predicted to the original dataframe
    df_orig2["IsDoHPredicted"] = df_pp2["IsDoHPredicted"]
    # non-443 rows will be NaN, replace with False
    df_orig2["IsDoHPredicted"] = df_orig2["IsDoHPredicted"].fillna(False)

    return df_orig2

# %%
results_df = pd.read_feather(f"cached/robustness.balanced_mix-results.p3.{p3version}.ft")
results_df["skips_and_weights"] = results_df["skips_and_weights"].apply(str)
model, normed, skips_and_weights_str, auc, fprs, tprs, thresholds = results_df[
    (results_df["model"] == model) & (results_df["normed"] == normed) & (results_df["skips_and_weights"] == str(np.array(skips_and_weights)))
].iloc[0]

# %%
data = {}
for sensitivity in [0.8, 0.9]:
    threshold = [threshold for tpr, threshold in zip(tprs, thresholds) if tpr >= sensitivity][0]
    df_pred = predict(pp_b2, clf, threshold, df_b2_pp, df_b2)
    data[sensitivity] = {
        'df': df_pred,  # dataframe with predicted values,
        'threshold': threshold,
    }

# %%
def calc(df_n):
    def rate(df_h):
        dns_packets = df_h[df_h["IsDoHPredicted"] == True]["uint32 PACKETS"].sum()  # outgoing packets
        non_dns_ips = set(df_h[df_h["IsDoHPredicted"] == False]["ipaddr SRC_IP"].unique()).union(
            set(df_h[df_h["IsDoHPredicted"] == False]["ipaddr DST_IP"].unique()))
        rate = float(dns_packets) / (1.0 + len(non_dns_ips))
        return {"dns_packets": dns_packets, "non_dns": len(non_dns_ips), "rate": rate, "rate_log": np.log(rate)}

    return pd.DataFrame({ ip: rate(grp) for ip, grp in df_n.groupby(["ipaddr SRC_IP"]) }).T.reset_index()

# %% [markdown]
# #### Calculate ratio on the whole dataset

# %%
for sensitivity, value in data.items():
    print(sensitivity)
    df_pred = value["df"]
    local_df = df_pred[df_pred["ipaddr SRC_IP"].str.startswith("192.168")]
    display(calc(local_df))
# Out:
# 0.8
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# RuntimeWarning: divide by zero encountered in log
# 2023-03-25 09:34:13,680 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2023-03-25 09:34:18,281 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2023-03-25 09:34:21,220 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2023-03-25 09:34:27,544 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2023-03-25 09:34:30,493 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2023-03-25 09:34:34,991 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2023-03-25 09:34:40,183 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2023-03-25 09:34:42,833 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2023-03-25 09:34:46,257 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2023-03-25 09:34:50,888 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2023-03-25 09:34:54,407 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2023-03-25 09:34:59,525 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2023-03-25 09:35:04,086 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2023-03-25 09:35:07,305 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2023-03-25 09:35:13,691 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2023-03-25 09:35:18,346 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# RuntimeWarning: divide by zero encountered in log
# UserWarning: Distributing <class 'dict'> object. This may take some time.
#            index  dns_packets  non_dns          rate   rate_log
# 0    192.168.1.1          0.0      2.0      0.000000       -inf
# 1  192.168.2.149     293700.0   4260.0     68.927482   4.233055
# 2  192.168.2.217     569784.0     16.0  33516.705882  10.419799
# 3  192.168.2.249     205116.0   3398.0     60.345984   4.100094
# 4   192.168.2.42          0.0      5.0      0.000000       -inf
# 0.9
# 2023-03-25 09:35:22,944 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2023-03-25 09:35:26,572 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2023-03-25 09:35:29,246 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# RuntimeWarning: divide by zero encountered in log
# 2023-03-25 09:35:33,299 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2023-03-25 09:35:38,419 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2023-03-25 09:35:40,872 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2023-03-25 09:35:45,333 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2023-03-25 09:35:49,604 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2023-03-25 09:35:52,491 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2023-03-25 09:36:28,150 - distributed.worker - ERROR - Exception during execution of task lambda-e3d731d230b4b8cda38863447ebfa805.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'apply_func-b06246c3-9470-4639-9ff6-0c09ea44da0a'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'apply_func-b06246c3-9470-4639-9ff6-0c09ea44da0a'
# RuntimeWarning: divide by zero encountered in log
# UserWarning: Distributing <class 'dict'> object. This may take some time.
#            index  dns_packets  non_dns          rate   rate_log
# 0    192.168.1.1          0.0      2.0      0.000000       -inf
# 1  192.168.2.149     349716.0   3900.0     89.647783   4.495888
# 2  192.168.2.217     802994.0     14.0  53532.933333  10.888052
# 3  192.168.2.249     266504.0   3122.0     85.335895   4.446595
# 4   192.168.2.42          0.0      5.0      0.000000       -inf

# %% [markdown]
# #### Split into time windows

# %%
min_ts = df_b2["time TIME_FIRST"].apply(dateutil.parser.parse).min()
min_ts
# Out:
# Timestamp('2023-03-23 14:50:04.316951')

# %%
local_ips = df_b2[df_b2["ipaddr SRC_IP"].str.startswith("192.168")]["ipaddr SRC_IP"].unique().tolist()
local_ips
# Out:
# 2023-03-25 09:37:36,199 - distributed.worker - ERROR - Exception during execution of task lambda-e44a1a21061be4942b1c516c5c300bc0.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'apply_func-868fa70d-59e8-49db-8b15-2f9c8eeb19f4'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'apply_func-868fa70d-59e8-49db-8b15-2f9c8eeb19f4'
# ['192.168.2.249',
#  '192.168.2.149',
#  '192.168.2.42',
#  '192.168.2.217',
#  '192.168.1.1']

# %%
f = '3min'

for sensitivity, value in data.items():
    print(sensitivity)

    df_pred = value["df"]
    local_df = df_pred[df_pred["ipaddr SRC_IP"].str.startswith("192.168")].copy()
    local_df["time TIME_FIRST"] = local_df["time TIME_FIRST"].apply(dateutil.parser.parse)
    
    calc_ips = {}

    a1_t = local_df.set_index(["time TIME_FIRST"])

    df_resample = a1_t.groupby(pd.Grouper(freq=f, origin=min_ts)).first()
    times = df_resample.index.tolist()
    ranges = list(zip(times, times[1:]))

    df_calcs = []
    for ran in ranges:
        df_ran = a1_t[(a1_t.index > ran[0]) & (a1_t.index < ran[1])]
        df_calc = calc(df_ran)
        df_calc["ts"] = ran[0]
        df_calcs.append(df_calc)

    value["df_calc"] = pd.concat(df_calcs).reset_index(drop=True)
# Out:
# 0.8
# 2023-03-25 09:37:47,688 - distributed.worker - ERROR - Exception during execution of task lambda-0fb3734692fe760b0e78b859137635fa.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-e511dabb-f4e5-478c-ab6a-dbfbec6d29ed'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-e511dabb-f4e5-478c-ab6a-dbfbec6d29ed'
# UserWarning: `DataFrame.groupby_on_multiple_columns` is not currently supported by PandasOnDask, defaulting to pandas implementation.
# FutureWarning: The `squeeze` parameter is deprecated and will be removed in a future version.
# UserWarning: Distributing <class 'pandas.core.frame.DataFrame'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 09:38:03,624 - distributed.worker - ERROR - Exception during execution of task lambda-58fc1d0aecb495e1220517149b0cff6b.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-106be056-2a7a-43f6-a2f6-1be30c48f54d'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-106be056-2a7a-43f6-a2f6-1be30c48f54d'
# 2023-03-25 09:38:05,535 - distributed.worker - ERROR - Exception during execution of task lambda-84a51a40fe784d1443d8813090aea298.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-857c320b-d83b-44b4-9bee-2c098a88fc73'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-857c320b-d83b-44b4-9bee-2c098a88fc73'
# RuntimeWarning: divide by zero encountered in log
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 09:38:15,446 - distributed.worker - ERROR - Exception during execution of task lambda-05f24b702310e01d328fac58682437a6.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-0426b45c-d163-4a40-a29b-1cb4cf11b498'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-0426b45c-d163-4a40-a29b-1cb4cf11b498'
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 09:38:20,275 - distributed.worker - ERROR - Exception during execution of task lambda-d4c8743949d7218c1c85a7352b10d167.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-7ebc372a-4bc6-4251-bd55-7a31efc7c661'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-7ebc372a-4bc6-4251-bd55-7a31efc7c661'
# RuntimeWarning: divide by zero encountered in log
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 09:38:30,369 - distributed.worker - ERROR - Exception during execution of task lambda-599cf623f373b239d1b4da0d97a1620b.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-658314b3-77db-4254-a31c-b44b68b11545'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-658314b3-77db-4254-a31c-b44b68b11545'
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# RuntimeWarning: divide by zero encountered in log
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 09:38:43,998 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# RuntimeWarning: divide by zero encountered in log
# 2023-03-25 09:38:49,166 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2023-03-25 09:38:54,652 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# RuntimeWarning: divide by zero encountered in log
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 09:39:00,218 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 09:39:05,679 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# RuntimeWarning: divide by zero encountered in log
# RuntimeWarning: divide by zero encountered in log
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 09:39:11,060 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2023-03-25 09:39:13,441 - distributed.worker - ERROR - Exception during execution of task lambda-162dc06d2d33e6eb23f5a1f1bce11d62.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-5749b791-139d-46d7-be3e-dce9ad5ddf36'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-5749b791-139d-46d7-be3e-dce9ad5ddf36'
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 09:39:16,729 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2023-03-25 09:39:18,242 - distributed.worker - ERROR - Exception during execution of task lambda-6fcd2a1cbb3d09a520d2cdaced192544.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-f4a295f2-d5a2-4cb2-af58-a8b38e846a7a'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-f4a295f2-d5a2-4cb2-af58-a8b38e846a7a'
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 09:39:20,452 - distributed.worker - ERROR - Exception during execution of task lambda-193bd2cebc7df6ea6db277e4d5ecd89b.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-1a0fe445-6800-491e-a926-031ca4212704'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-1a0fe445-6800-491e-a926-031ca4212704'
# 2023-03-25 09:39:22,652 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# UserWarning: `Series.to_numpy` for empty DataFrame is not currently supported by PandasOnDask, defaulting to pandas implementation.
# UserWarning: `Series.to_numpy` for empty DataFrame is not currently supported by PandasOnDask, defaulting to pandas implementation.
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 09:39:28,481 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2023-03-25 09:39:30,045 - distributed.worker - ERROR - Exception during execution of task lambda-247b86a9e367393511f9a72207edafbd.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-736d3377-3696-4d95-a75c-d042cc06f0dd'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-736d3377-3696-4d95-a75c-d042cc06f0dd'
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 09:39:34,210 - distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# 2023-03-25 09:39:35,445 - distributed.worker - ERROR - Exception during execution of task lambda-6c3203bf612b3dddd1e22d980781bb0c.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-93e6a50c-cb48-446e-89fa-68537acd4b2a'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-93e6a50c-cb48-446e-89fa-68537acd4b2a'
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 09:39:40,289 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2023-03-25 09:39:43,344 - distributed.worker - ERROR - Exception during execution of task lambda-3eeedf18be88991a72c409fbee3035b9.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func

#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-b2cd6d74-3004-41bd-8383-be27e6730312'
# 2023-03-25 09:50:34,793 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# RuntimeWarning: divide by zero encountered in log
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 09:50:38,437 - distributed.worker - ERROR - Exception during execution of task lambda-edf1e7d04d17486aed189ebb3a298a47.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-c75da373-4a02-4989-9451-e137b84a8420'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-c75da373-4a02-4989-9451-e137b84a8420'
# 2023-03-25 09:50:42,003 - distributed.worker - ERROR - Exception during execution of task lambda-34351c2116c0b3f4939fd4c897463756.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-94de1196-d049-4198-b56a-cfb32aa47854'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-94de1196-d049-4198-b56a-cfb32aa47854'
# 2023-03-25 09:50:45,749 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 2023-03-25 09:50:46,509 - distributed.worker - ERROR - Exception during execution of task lambda-2a0fdd089f32f32eb401ff574657e945.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-b4d171bb-759a-48d2-9964-7ba8103e0ec9'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-b4d171bb-759a-48d2-9964-7ba8103e0ec9'
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-25 09:50:52,265 - distributed.worker - WARNING - Could not find data: {'function-a07cbcc39f974466a482b6bb0af2bca5': ['tcp://127.0.0.1:35567', 'tcp://127.0.0.1:45795', 'tcp://127.0.0.1:39595', 'tcp://127.0.0.1:32911', 'tcp://127.0.0.1:46135', 'tcp://127.0.0.1:38707', 'tcp://127.0.0.1:37817', 'tcp://127.0.0.1:41943', 'tcp://127.0.0.1:35651']} on workers: [] (who_has: {'function-a07cbcc39f974466a482b6bb0af2bca5': ['tcp://127.0.0.1:35567', 'tcp://127.0.0.1:45795', 'tcp://127.0.0.1:39595', 'tcp://127.0.0.1:32911', 'tcp://127.0.0.1:46135', 'tcp://127.0.0.1:38707', 'tcp://127.0.0.1:37817', 'tcp://127.0.0.1:41943', 'tcp://127.0.0.1:35651']})
# 2023-03-25 09:50:52,267 - distributed.scheduler - WARNING - Worker tcp://127.0.0.1:45925 failed to acquire keys: {'function-a07cbcc39f974466a482b6bb0af2bca5': ('tcp://127.0.0.1:35567', 'tcp://127.0.0.1:45795', 'tcp://127.0.0.1:39595', 'tcp://127.0.0.1:32911', 'tcp://127.0.0.1:46135', 'tcp://127.0.0.1:38707', 'tcp://127.0.0.1:37817', 'tcp://127.0.0.1:41943', 'tcp://127.0.0.1:35651')}
# 2023-03-25 09:50:56,372 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# UserWarning: Distributing <class 'dict'> object. This may take some time.

# %%
#| label: fig-rate_log-flubot-exp-1-2
#| fig-cap: $\rho(a)$ plot for all instances (B2 period)
#| fig-subcap: 
#|   - "sensitivity 0.8"
#|   - "sensitivity 0.9"

import matplotlib.pyplot as plt

for sensitivity, value in data.items():
    print(sensitivity)
    fig, axs = plt.subplots(ncols=1, figsize=(12, 4))
    df_calcs = value["df_calc"]
    for host in local_ips:
        df_calc_host = df_calcs[df_calcs["index"] == host].set_index("ts")
        df_calc_host["rate_log"].plot(label=f'{host}', ax=axs)

    plt.ylim(ymin=0)
    plt.title(f"Sensitivity: {sensitivity}, threshold: {value['threshold']}")
    plt.legend()
    plt.show()
# Out:
# 0.8
# 2023-03-25 09:51:02,665 - distributed.worker - ERROR - Exception during execution of task lambda-17609652c83d01fb758fb36cd5ba5f5d.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'apply_list_of_funcs-9bddd4c8-1532-4b87-842f-22cbed0bdfd5'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'apply_list_of_funcs-9bddd4c8-1532-4b87-842f-22cbed0bdfd5'
# 2023-03-25 09:51:02,863 - distributed.worker - ERROR - Exception during execution of task lambda-5a6ecd257808bf913ad6d677324e58db.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'apply_list_of_funcs-6a42781d-eeee-445e-95dc-2ffe48eacbb6'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'apply_list_of_funcs