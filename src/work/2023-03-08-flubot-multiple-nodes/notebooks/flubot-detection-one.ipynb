# %% [markdown]
# ---
# execute:
#   echo: true
#   enabled: false
#   output: true
#   warning: false
# format:
#     html:
#         code-fold: false
# ---

# %% [markdown]
# ## Predict DoH traffic

# %% [markdown]
# The model deployment is done in two stages: I. tune the model, II. turn on the malware detection (on the data collected in B1 and B2 periods respectively, described in the timeline @fig-timeline)
#
# ![Timeline](../../imgs/timeline.png)
#
# ### Stage I: Model tuning
#
# On this state we fit the scaler on the data collected in B1 period, to be used later on the second stage

# %%
#| echo: false
#| output: false
basepath = "/home/u1/"

# %%
#| echo: false
#| output: false
import os
os.environ["MODIN_ENGINE"] = "dask"
import modin.pandas as pd
import numpy as np

pd.set_option("display.max_columns", None)

# %%
from detect_common import *

# %%
#| output: false
p1version = "v6"
p2version = "v7"
p3version = "v5"

# %%
model = 'RF'
normed = True
skips_and_weights = [2,4,0,0]

# %%
import dateutil.parser

df_b1 = pd.read_feather("cached/v5_1.ft")
# Out:
# UserWarning: Dask execution environment not yet initialized. Initializing...
# To remove this warning, run the following python code before doing dataframe operations:
#
#     from distributed import Client
#
#     client = Client()
#
# UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 45685 instead
# 2023-03-24 22:16:30,418 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-sujcmwub', purging
# 2023-03-24 22:16:30,419 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-lqj17nh5', purging
# 2023-03-24 22:16:30,420 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-ho4b1hwq', purging
# 2023-03-24 22:16:30,420 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-xwv9e8uk', purging
# 2023-03-24 22:16:30,420 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-yj_1h9ao', purging
# 2023-03-24 22:16:30,421 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-st7a9yxr', purging
# 2023-03-24 22:16:30,421 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-tro22769', purging
# 2023-03-24 22:16:30,421 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-kptmau2d', purging
# 2023-03-24 22:16:30,422 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-nhact7f5', purging
# 2023-03-24 22:16:30,422 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-t21mqd1o', purging
# 2023-03-24 22:16:30,422 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-khc88vw9', purging
# 2023-03-24 22:16:30,423 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-jgy6k69v', purging
# 2023-03-24 22:16:30,423 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-k5kf5noi', purging
# 2023-03-24 22:16:30,424 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-p7k25ulx', purging
# 2023-03-24 22:16:30,424 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-1p4ymmam', purging
# 2023-03-24 22:16:30,424 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-ikkwi1av', purging
# 2023-03-24 22:16:30,425 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-m8ex2v0k', purging
# 2023-03-24 22:16:30,425 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-3hl3vndx', purging

# %%
path_doh_ips_androids = basepath + "datasets/flubot20230323/data/v5_benign_doh_ips.csv"
path_doh_ips_general = "doh_resolver_ip.csv"
full_list = get_doh_ips(path_doh_ips_androids) + get_doh_ips(path_doh_ips_general)

cp = CacheableProcessing(100, 100, full_list)
df_b1_p = cp.process(df_b1, f"cached/v5_1.p3.{p3version}.cp.ft")
# Out:
# UserWarning: `Series.tolist` is not currently supported by PandasOnDask, defaulting to pandas implementation.
# Please refer to https://modin.readthedocs.io/en/stable/supported_apis/defaulting_to_pandas.html for explanation.
# UserWarning: `Series.tolist` is not currently supported by PandasOnDask, defaulting to pandas implementation.
# UserWarning: Defaulting to pandas implementation.
# Reason: `lines` argument not supported
# FutureWarning: the 'numpy' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'numpy'

# %%
from joblib import dump, load

name = (
    ('normed-' if normed else 'unnormed-') + 
    '-'.join(str(p) for p in skips_and_weights)
)

clf = load(f'models/{model}-mix-1-p-{name}.p1.{p1version}.p2.{p2version}.joblib')

# %%
pp_b1 = PreProcessing(normed, *skips_and_weights)

df_b1_pp = pp_b1.process(
    df_b1_p,
    f"cached/p3.{p3version}.pp.{model}-{name}.saved", 
    fit_new_scaler=True
)
# Out:
# UserWarning: Defaulting to pandas implementation.
# Reason: `lines` argument not supported
# FutureWarning: the 'numpy' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'numpy'
# UserWarning: Defaulting to pandas implementation.
# Reason: `lines` argument not supported
# FutureWarning: the 'numpy' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'numpy'
# UserWarning: Defaulting to pandas implementation.
# Reason: `lines` argument not supported
# FutureWarning: the 'numpy' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'numpy'

# %%
pp_b1.store_scaler(
    f"cached/p3.{p3version}.pp.{model}-{name}.scaler"
)

# %% [markdown]
# ### Stage II: Malware detection
#
# On this state we turn on the malware detection, provisioning the model with the scaler trained before. For malware detection we use the data trained in B2 period.

# %%
df_b2 = pd.read_feather("cached/v5_2.ft")

# %%
cp = CacheableProcessing(100, 100, full_list)
df_b2_p = cp.process(df_b2, f"cached/v5_2.p3.{p3version}.cp.ft")
# Out:
# UserWarning: Defaulting to pandas implementation.
# Reason: `lines` argument not supported
# FutureWarning: the 'numpy' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'numpy'

# %%
pp_b2 = PreProcessing(normed, *skips_and_weights)
pp_b2.load_scaler(
    f"cached/p3.{p3version}.pp.{model}-{name}.scaler"
)
df_b2_pp, df_b2_pp_features, df_b2_pp_labels = pp_b2.process(
    df_b2_p,
    f"cached/b2.p3.{p3version}.pp.{model}-{name}.saved", 
    fit_new_scaler=False  # use scaler trained in B1
)
# Out:
# UserWarning: Defaulting to pandas implementation.
# Reason: `lines` argument not supported
# FutureWarning: the 'numpy' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'numpy'
# UserWarning: Defaulting to pandas implementation.
# Reason: `lines` argument not supported
# FutureWarning: the 'numpy' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'numpy'
# UserWarning: Defaulting to pandas implementation.
# Reason: `lines` argument not supported
# FutureWarning: the 'numpy' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'numpy'

# %%
def predict(pp, clf, threshold, df_pp, df_orig):
    """
    pp: PreProcessing object
    clf: classifier
    threshold: >=threshold for positive (DoH) class
    df_pp: preprocessed dataframe
    df_orig: unprocessed dataframe
    """
    df_pp2 = df_pp.copy()

    df_pp2["IsDoHPredicted"] = (clf.predict_proba(df_pp2[pp.feature_fields])[:,1] >= threshold).astype(bool)

    df_orig2 = df_orig.copy()
    # fill predicted to the original dataframe
    df_orig2["IsDoHPredicted"] = df_pp2["IsDoHPredicted"]
    # non-443 rows will be NaN, replace with False
    df_orig2["IsDoHPredicted"] = df_orig2["IsDoHPredicted"].fillna(False)

    return df_orig2

# %%
results_df = pd.read_feather(f"cached/robustness.balanced_mix-results.p3.{p3version}.ft")
results_df["skips_and_weights"] = results_df["skips_and_weights"].apply(str)
model, normed, skips_and_weights_str, auc, fprs, tprs, thresholds = results_df[
    (results_df["model"] == model) & (results_df["normed"] == normed) & (results_df["skips_and_weights"] == str(np.array(skips_and_weights)))
].iloc[0]

# %%
data = {}
for sensitivity in [0.8, 0.9]:
    threshold = [threshold for tpr, threshold in zip(tprs, thresholds) if tpr >= sensitivity][0]
    df_pred = predict(pp_b2, clf, threshold, df_b2_pp, df_b2)
    data[sensitivity] = {
        'df': df_pred,  # dataframe with predicted values,
        'threshold': threshold,
    }

# %%
def calc(df_n):
    def rate(df_h):
        dns_packets = df_h[df_h["IsDoHPredicted"] == True]["uint32 PACKETS"].sum()  # outgoing packets
        non_dns_ips = set(df_h[df_h["IsDoHPredicted"] == False]["ipaddr SRC_IP"].unique()).union(
            set(df_h[df_h["IsDoHPredicted"] == False]["ipaddr DST_IP"].unique()))
        rate = float(dns_packets) / (1.0 + len(non_dns_ips))
        return {"dns_packets": dns_packets, "non_dns": len(non_dns_ips), "rate": rate, "rate_log": np.log(rate)}

    return pd.DataFrame({ ip: rate(grp) for ip, grp in df_n.groupby(["ipaddr SRC_IP"]) }).T.reset_index()

# %% [markdown]
# #### Calculate ratio on the whole dataset

# %%
for sensitivity, value in data.items():
    print(sensitivity)
    df_pred = value["df"]
    local_df = df_pred[df_pred["ipaddr SRC_IP"].str.startswith("192.168")]
    display(calc(local_df))
# Out:
# 0.4
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# RuntimeWarning: divide by zero encountered in log
# 2023-03-24 22:18:54,172 - distributed.worker - ERROR - Exception during execution of task lambda-6c9300abee0008f1d9480369eb8c7f79.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'apply_func-6b6feb56-6856-4160-be1f-77025cb20d41'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'apply_func-6b6feb56-6856-4160-be1f-77025cb20d41'
# RuntimeWarning: divide by zero encountered in log
# UserWarning: Distributing <class 'dict'> object. This may take some time.
#            index  dns_packets  non_dns       rate  rate_log
# 0    192.168.1.1          0.0      2.0   0.000000      -inf
# 1  192.168.2.149      98863.0   4892.0  20.204987  3.005929
# 2  192.168.2.217       1766.0     24.0  70.640000  4.257597
# 3  192.168.2.249      23972.0   3830.0   6.257374  1.833761
# 4   192.168.2.42          0.0      5.0   0.000000      -inf
# 0.6
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# RuntimeWarning: divide by zero encountered in log
# RuntimeWarning: divide by zero encountered in log
# UserWarning: Distributing <class 'dict'> object. This may take some time.
#            index  dns_packets  non_dns         rate  rate_log
# 0    192.168.1.1          0.0      2.0     0.000000      -inf
# 1  192.168.2.149     155933.0   4759.0    32.759034  3.489179
# 2  192.168.2.217     126365.0     23.0  5265.208333  8.568876
# 3  192.168.2.249      71611.0   3748.0    19.101360  2.949760
# 4   192.168.2.42          0.0      5.0     0.000000      -inf
# 0.8
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-24 22:21:59,787 - distributed.worker - ERROR - Exception during execution of task lambda-30e2746ab9a3e1875b04ce0c1fdb96e8.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-55a4e020-0a8d-4388-a60e-c1c856ca0a3c'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-55a4e020-0a8d-4388-a60e-c1c856ca0a3c'
# RuntimeWarning: divide by zero encountered in log
# 2023-03-24 22:22:21,962 - distributed.worker - ERROR - Exception during execution of task lambda-24272729780b2f6307a0693df604ca87.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'apply_func-7e20d61e-b88b-418d-bb05-82d7773bbddb'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'apply_func-7e20d61e-b88b-418d-bb05-82d7773bbddb'
# RuntimeWarning: divide by zero encountered in log
# UserWarning: Distributing <class 'dict'> object. This may take some time.
#            index  dns_packets  non_dns          rate  rate_log
# 0    192.168.1.1          0.0      2.0      0.000000      -inf
# 1  192.168.2.149     230029.0   4508.0     51.015525  3.932130
# 2  192.168.2.217     334045.0     17.0  18558.055556  9.828659
# 3  192.168.2.249     140504.0   3575.0     39.290828  3.670991
# 4   192.168.2.42          0.0      5.0      0.000000      -inf
# 0.9
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# RuntimeWarning: divide by zero encountered in log
# RuntimeWarning: divide by zero encountered in log
# UserWarning: Distributing <class 'dict'> object. This may take some time.
#            index  dns_packets  non_dns          rate   rate_log
# 0    192.168.1.1          0.0      2.0      0.000000       -inf
# 1  192.168.2.149     271287.0   4303.0     63.031366   4.143632
# 2  192.168.2.217     609350.0     17.0  33852.777778  10.429776
# 3  192.168.2.249     184519.0   3414.0     54.031918   3.989575
# 4   192.168.2.42          0.0      5.0      0.000000       -inf

# %% [markdown]
# #### Split into time windows

# %%
min_ts = df_b2["time TIME_FIRST"].apply(dateutil.parser.parse).min()
min_ts
# Out:
# Timestamp('2023-03-23 14:50:04.316951')

# %%
local_ips = df_b2[df_b2["ipaddr SRC_IP"].str.startswith("192.168")]["ipaddr SRC_IP"].unique().tolist()
local_ips
# Out:
# 2023-03-24 22:26:00,268 - distributed.worker - ERROR - Exception during execution of task lambda-ab8a082afb47287c2141918000666fba.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'apply_func-3e15d438-033b-4443-8f0e-091fb128e0a7'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'apply_func-3e15d438-033b-4443-8f0e-091fb128e0a7'
# 2023-03-24 22:26:00,367 - distributed.worker - ERROR - Exception during execution of task lambda-24c40e18ee513595db62011dde9a755a.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'apply_func-6efc375b-37de-4e3b-8857-a0dfd4b7ebb8'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'apply_func-6efc375b-37de-4e3b-8857-a0dfd4b7ebb8'
# ['192.168.2.249',
#  '192.168.2.149',
#  '192.168.2.42',
#  '192.168.2.217',
#  '192.168.1.1']

# %%
f = '3min'

for sensitivity, value in data.items():
    print(sensitivity)

    df_pred = value["df"]
    local_df = df_pred[df_pred["ipaddr SRC_IP"].str.startswith("192.168")].copy()
    local_df["time TIME_FIRST"] = local_df["time TIME_FIRST"].apply(dateutil.parser.parse)
    
    calc_ips = {}

    a1_t = local_df.set_index(["time TIME_FIRST"])

    df_resample = a1_t.groupby(pd.Grouper(freq=f, origin=min_ts)).first()
    times = df_resample.index.tolist()
    ranges = list(zip(times, times[1:]))

    df_calcs = []
    for ran in ranges:
        df_ran = a1_t[(a1_t.index > ran[0]) & (a1_t.index < ran[1])]
        df_calc = calc(df_ran)
        df_calc["ts"] = ran[0]
        df_calcs.append(df_calc)

    value["df_calc"] = pd.concat(df_calcs).reset_index(drop=True)
# Out:
# 0.4
# 2023-03-24 22:26:12,045 - distributed.worker - ERROR - Exception during execution of task lambda-2821c483494373265c578ce67d18c156.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-bfacf9bb-0645-4c84-b025-747c4f3c479a'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-
- distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2023-03-24 22:29:56,810 - distributed.worker - ERROR - Exception during execution of task lambda-618f6c96b84911568758b36c27591dc9.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-11da076c-ee13-44ac-b99f-a111cff2af4c'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-11da076c-ee13-44ac-b99f-a111cff2af4c'
# 2023-03-24 22:30:00,417 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2023-03-24 22:30:00,474 - distributed.worker - ERROR - Exception during execution of task lambda-4e5a910f0b2bb0ab5091357ce47ce3c4.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-500171c4-2151-418b-924c-0df832875172'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-500171c4-2151-418b-924c-0df832875172'
# RuntimeWarning: divide by zero encountered in log
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# 2023-03-24 22:30:01,864 - distributed.worker - ERROR - Exception during execution of task lambda-26270ba734c81b5e651ed57c71b34a3e.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'apply_list_of_funcs-e79556dc-5cb5-42a6-a1df-2482a1fb06f3'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'apply_list_of_funcs-e79556dc-5cb5-42a6-a1df-2482a1fb06f3'
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-24 22:30:04,410 - distributed.worker - ERROR - Exception during execution of task lambda-482654ade6bf0bf70fd42ba847cc0fb2.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'apply_func-320769b2-03c0-4ac3-b6b0-954838c8540b'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'apply_func-320769b2-03c0-4ac3-b6b0-954838c8540b'
# 2023-03-24 22:30:05,517 - distributed.worker - ERROR - Exception during execution of task lambda-975b3c542a68dd65c6ea8bf0a5afc3cc.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'apply_func-a2c4dde1-28f2-4687-af38-3d36189c343e'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'apply_func-a2c4dde1-28f2-4687-af38-3d36189c343e'
# 2023-03-24 22:30:06,569 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2023-03-24 22:30:07,800 - distributed.worker - ERROR - Exception during execution of task lambda-4b2fe3496ea786a4c008a6547742d907.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-60fcbeac-6bd5-48c7-8161-63b28178e563'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-60fcbeac-6bd5-48c7-8161-63b28178e563'
# 2023-03-24 22:30:11,714 - distributed.worker - ERROR - Exception during execution of task lambda-677c484316042bebda9ae66d23b81948.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-02e7458a-6990-4085-aefb-50244e0740bb'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-02e7458a-6990-4085-aefb-50244e0740bb'
# 2023-03-24 22:30:12,932 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# UserWarning: Group indices computation is not currently supported by PandasOnDask, defaulting to pandas implementation.
# 2023-03-24 22:30:19,171 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# 2023-03-24 22:30:21,101 - distributed.worker - ERROR - Exception during execution of task lambda-8b7aa7337ce0c29664d393e197d1c03f.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: '_deploy_dask_func-d0c350f9-908f-4f2e-afeb-919411733c2d'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: '_deploy_dask_func-d0c350f9-908f-4f2e-afeb-919411733c2d'
# 2023-03-24 22:30:22,411 - distributed.worker - ERROR - Exception during execution of task lambda-f82d6b845e966231cb491cea0af88356.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'apply_func-a2cbcc0d-1c0b-4af3-b831-ef47d3c4063b'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'apply_func-a2cbcc0d-1c0b-4af3-b831-ef47d3c4063b'
# 2023-03-24 22:30:26,011 - distributed.utils_perf - WARNING - full garbage collections took 14% CPU time recently (threshold: 10%)
# RuntimeWarning: divide by zero encountered in log
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# ...
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'apply_func-04ee71e2-6851-4755-a82c-4b27d5230e1b'
# 2023-03-24 22:35:25,467 - distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# 2023-03-24 22:35:31,593 - distributed.worker - ERROR - Exception during execution of task lambda-3b1564d465b267322b91fa36183e47f6.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2390, in _prepare_args_for_execution
#     data[k] = self.data[k]
#   File "/opt/conda/lib/python3.10/site-packages/distributed/spill.py", line 245, in __getitem__
#     return super().__getitem__(key)
#   File "/opt/conda/lib/python3.10/site-packages/zict/buffer.py", line 108, in __getitem__
#     raise KeyError(key)
# KeyError: 'apply_func-18d0024c-ae3a-48bf-ab99-768b04a465de'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2271, in execute
#     args2, kwargs2 = self._prepare_args_for_execution(ts, args, kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/distributed/worker.py", line 2394, in _prepare_args_for_execution
#     data[k] = Actor(type(self.state.actors[k]), self.address, k, self)
# KeyError: 'apply_func-18d0024c-ae3a-48bf-ab99-768b04a465de'
# UserWarning: Distributing <class 'dict'> object. This may take some time.
# 2023-03-24 22:35:33,944 - distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# 0.8
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 7
#       4 print(sensitivity)
#       6 df_pred = value["df"]
# ----> 7 local_df = df_pred[df_pred["ipaddr SRC_IP"].str.startswith("192.168")].copy()
#       8 local_df["time TIME_FIRST"] = local_df["time TIME_FIRST"].apply(dateutil.parser.parse)
#      10 calc_ips = {}
#
# File /opt/conda/lib/python3.10/site-packages/modin/logging/logger_decorator.py:128, in enable_logging.<locals>.decorator.<locals>.run_and_log(*args, **kwargs)
#     113 """
#     114 Compute function with logging if Modin logging is enabled.
#     115
#    (...)
#     125 Any
#     126 """
#     127 if LogMode.get() == "disable":
# --> 128     return obj(*args, **kwargs)
#     130 logger = get_logger()
#     131 logger_level = getattr(logger, log_level)
#
# File /opt/conda/lib/python3.10/site-packages/modin/pandas/base.py:3681, in BasePandasDataset.__getitem__(self, key)
#    3679     return self._getitem_slice(indexer)
#    3680 else:
# -> 3681     return self._getitem(key)
#
# File /opt/conda/lib/python3.10/site-packages/modin/logging/logger_decorator.py:128, in enable_logging.<locals>.decorator.<locals>.run_and_log(*args, **kwargs)
#     113 """
#     114 Compute function with logging if Modin logging is enabled.
#     115
#    (...)
#     125 Any
#     126 """
#     127 if LogMode.get() == "disable":
# --> 128     return obj(*args, **kwargs)
#     130 logger = get_logger()
#     131 logger_level = getattr(logger, log_level)
#
# File /opt/conda/lib/python3.10/site-packages/modin/pandas/dataframe.py:3193, in DataFrame._getitem(self, key)
#    3190     pass
#    3191 if isinstance(key, Series):
#    3192     return self.__constructor__(
# -> 3193         query_compiler=self._query_compiler.getitem_array(key._query_compiler)
#    3194     )
#    3195 elif isinstance(key, (np.ndarray, pandas.Index, list)):
#    3196     return self.__constructor__(
#    3197         query_compiler=self._query_compiler.getitem_array(key)
#    3198     )
#
# File /opt/conda/lib/python3.10/site-packages/modin/logging/logger_decorator.py:128, in enable_logging.<locals>.decorator.<locals>.run_and_log(*args, **kwargs)
#     113 """
#     114 Compute function with logging if Modin logging is enabled.
#     115
#    (...)
#     125 Any
#     126 """
#     127 if LogMode.get() == "disable":
# --> 128     return obj(*args, **kwargs)
#     130 logger = get_logger()
#     131 logger_level = getattr(logger, log_level)
#
# File /opt/conda/lib/python3.10/site-packages/modin/core/storage_formats/pandas/query_compiler.py:2380, in PandasQueryCompiler.getitem_array(self, key)
#    2378     if len(key.dtypes) == 1 and is_bool_dtype(key.dtypes[0]):
#    2379         self.__validate_bool_indexer(key.index)
# -> 2380         return self.__getitem_bool(key, broadcast=True, dtypes="copy")
#    2382     key = key.to_pandas().squeeze(axis=1)
#    2384 if is_bool_indexer(key):
#
# File /opt/conda/lib/python3.10/site-packages/modin/logging/logger_decorator.py:128, in enable_logging.<locals>.decorator.<locals>.run_and_log(*args, **kwargs)
#     113 """
#     114 Compute function with logging if Modin logging is enabled.
#     115
#    (...)
#     125 Any
#     126 """
#     127 if LogMode.get() == "disable":
# --> 128     return obj(*args, **kwargs)
#     130 logger = get_logger()
#     131 logger_level = getattr(logger, log_level)
#
# File /opt/conda/lib/python3.10/site-packages/modin/core/dataframe/algebra/binary.py:224, in Binary.register.<locals>.caller(query_compiler, other, broadcast, dtypes, *args, **kwargs)
#     217         if (
#     218             len(self_columns) == 1
#     219             and len(other.columns) == 1
#     220             and self_columns.equals(other.columns)
#     221         ):
#     222             shape_hint = "column"
#     223     return query_compiler.__constructor__(
# --> 224         query_compiler._modin_frame.broadcast_apply(
#     225             axis,
#     226             lambda left, right: func(
#     227                 left, right.squeeze(), *args, **kwargs
#     228             ),
#     229             other._modin_frame,
#     230             join_type=join_type,
#     231             labels=labels,
#     232             dtypes=dtypes,
#     233         ),
#     234         shape_hint=shape_hint,
#     235     )
#     236 else:
#     237     if (
#     238         other._modin_frame._dtypes is not None
#     239         and query_compiler._modin_frame._dtypes is not None
#     240     ):
#
# File /opt/conda/lib/python3.10/site-packages/modin/logging/logger_decorator.py:128, in enable_logging.<locals>.decorator.<locals>.run_and_log(*args, **kwargs)
#     113 """
#     114 Compute function with logging if Modin logging is enabled.
#     115
#    (...)
#     125 Any
#     126 """
#     127 if LogMode.get() == "disable":
# --> 128     return obj(*args, **kwargs)
#     130 logger = get_logger()
#     131 logger_level = getattr(logger, log_level)
#
# File /opt/conda/lib/python3.10/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:126, in lazy_metadata_decorator.<locals>.decorator.<locals>.run_f_on_minimally_updated_metadata(self, *args, **kwargs)
#     124     elif apply_axis == "rows":
#     125         obj._propagate_index_objs(axis=0)
# --> 126 result = f(self, *args, **kwargs)
#     127 if apply_axis is None and not transpose:
#     128     result._deferred_index = self._deferred_index
#
# File /opt/conda/lib/python3.10/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:2564, in PandasDataframe.broadcast_apply(self, axis, func, other, join_type, labels, dtypes)
#    2562 # unwrap list returned by `copartition`.
#    2563 right_parts = right_parts[0]
# -> 2564 new_frame = self._partition_mgr_cls.broadcast_apply(
#    2565     axis, func, left_parts, right_parts
#    2566 )
#    2567 if dtypes == "copy":
#    2568     dtypes = self._dtypes
#
# File /opt/conda/lib/python3.10/site-packages/modin/logging/logger_decorator.py:128, in enable_logging.<locals>.decorator.<locals>.run_and_log(*args, **kwargs)
#     113 """
#     114 Compute function with logging if Modin logging is enabled.
#     115
#    (...)
#     125 Any
#     126 """
#     127 if LogMode.get() == "disable":
# --> 128     return obj(*args, **kwargs)
#     130 logger = get_logger()
#     131 logger_level = getattr(logger, log_level)
#
# File /opt/conda/lib/python3.10/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:58, in wait_computations_if_benchmark_mode.<locals>.wait(cls, *args, **kwargs)
#      55 @wraps(func)
#      56 def wait(cls, *args, **kwargs):
#      57     """Wait for computation results."""
# ---> 58     result = func(cls, *args, **kwargs)
#      59     if BenchmarkMode.get():
#      60         if isinstance(result, tuple):
#
# File /opt/conda/lib/python3.10/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:373, in PandasDataframePartitionManager.broadcast_apply(cls, axis, apply_func, left, right, other_name)
#     370 map_func = cls.preprocess_func(map_func)
#     371 rt_axis_parts = cls.axis_partition(right, axis ^ 1)
#     372 return np.array(
# --> 373     [
#     374         [
#     375             part.apply(
#     376                 map_func,
#     377                 *(
#     378                     rt_axis_parts[col_idx].list_of_blocks
#     379                     if axis
#     380                     else rt_axis_parts[row_idx].list_of_blocks
#     381                 ),
#     382             )
#     383             for col_idx, part in enumerate(left[row_idx])
#     384         ]
#     385         for row_idx in range(len(left))
#     386     ]
#     387 )
#
# File /opt/conda/lib/python3.10/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:374, in <listcomp>(.0)
#     370 map_func = cls.preprocess_func(map_func)
#     371 rt_axis_parts = cls.axis_partition(right, axis ^ 1)
#     372 return np.array(
#     373     [
# --> 374         [
#     375             part.apply(
#     376                 map_func,
#     377                 *(
#     378                     rt_axis_parts[col_idx].list_of_blocks
#     379                     if axis
#     380                     else rt_axis_parts[row_idx].list_of_blocks
#     381                 ),
#     382             )
#     383             for col_idx, part in enumerate(left[row_idx])
#     384         ]
#     385         for row_idx in range(len(left))
#     386     ]
#     387 )
#
# File /opt/conda/lib/python3.10/site-packages/modin/core/dataframe/pandas/partitioning/partition_manager.py:375, in <listcomp>(.0)
#     370 map_func = cls.preprocess_func(map_func)
#     371 rt_axis_parts = cls.axis_partition(right, axis ^ 1)
#     372 return np.array(
#     373     [
#     374         [
# --> 375             part.apply(
#     376                 map_func,
#     377                 *(
#     378                     rt_axis_parts[col_idx].list_of_blocks
#     379                     if axis
#     380                     else rt_axis_parts[row_idx].list_of_blocks
#     381                 ),
#     382             )
#     383             for col_idx, part in enumerate(left[row_idx])
#     384         ]
#     385         for row_idx in range(len(left))
#     386     ]
#     387 )
#
# File /opt/conda/lib/python3.10/site-packages/modin/core/execution/dask/implementations/pandas_on_dask/partitioning/partition.py:104, in PandasOnDaskDataframePartition.apply(self, func, *args, **kwargs)
#     100 else:
#     101     # We handle `len(call_queue) == 1` in a different way because
#     102     # this improves performance a bit.
#     103     func, f_args, f_kwargs = call_queue[0]
# --> 104     futures = DaskWrapper.deploy(
#     105         func=apply_func,
#     106         f_args=(self._data, func, *f_args),
#     107         f_kwargs=f_kwargs,
#     108         num_returns=2,
#     109         pure=False,
#     110     )
#     111 return self.__constructor__(futures[0], ip=futures[1])
#
# File /opt/conda/lib/python3.10/site-packages/modin/core/execution/dask/common/engine_wrapper.py:84, in DaskWrapper.deploy(cls, func, f_args, f_kwargs, num_returns, pure)
#      80     remote_task_future = client.submit(
#      81         _deploy_dask_func, func, *args, pure=pure, **kwargs
#      82     )
#      83 if num_returns != 1:
# ---> 84     return [
#      85         client.submit(lambda tup, i: tup[i], remote_task_future, i)
#      86         for i in range(num_returns)
#      87     ]
#      88 return remote_task_future
#
# File /opt/conda/lib/python3.10/site-packages/modin/core/execution/dask/common/engine_wrapper.py:85, in <listcomp>(.0)
#      80     remote_task_future = client.submit(
#      81         _deploy_dask_func, func, *args, pure=pure, **kwargs
#      82     )
#      83 if num_returns != 1:
#      84     return [
# ---> 85         client.submit(lambda tup, i: tup[i], remote_task_future, i)
#      86         for i in range(num_returns)
#      87     ]
#      88 return remote_task_future
#
# File /opt/conda/lib/python3.10/site-packages/distributed/client.py:1911, in Client.submit(self, func, key, workers, resources, retries, priority, fifo_timeout, allow_other_workers, actor, actors, pure, *args, **kwargs)
#    1908 else:
#    1909     dsk = {skey: (func,) + tuple(args)}
# -> 1911 futures = self._graph_to_futures(
#    1912     dsk,
#    1913     [skey],
#    1914     workers=workers,
#    1915     allow_other_workers=allow_other_workers,
#    1916     priority={skey: 0},
#    1917     user_priority=priority,
#    1918     resources=resources,
#    1919     retries=retries,
#    1920     fifo_timeout=fifo_timeout,
#    1921     actors=actor,
#    1922 )
#    1924 logger.debug("Submit %s(...), %s", funcname(func), key)
#    1926 return futures[skey]
#
# File /opt/conda/lib/python3.10/site-packages/distributed/client.py:3070, in Client._graph_to_futures(self, dsk, keys, workers, allow_other_workers, priority, user_priority, resources, retries, fifo_timeout, actors)
#    3058 # Create futures before sending graph (helps avoid contention)
#    3059 futures = {key: Future(key, self, inform=False) for key in keyset}
#    3061 self._send_to_scheduler(
#    3062     {
#    3063         "op": "update-graph-hlg",
#    3064         "hlg": dsk,
#    3065         "keys": list(map(stringify, keys)),
#    3066         "priority": priority,
#    3067         "submitting_task": getattr(thread_state, "key", None),
#    3068         "fifo_timeout": fifo_timeout,
#    3069         "actors": actors,
# -> 3070         "code": self._get_computation_code(),
#    3071     }
#    3072 )
#    3073 return futures
#
# File /opt/conda/lib/python3.10/site-packages/distributed/client.py:2998, in Client._get_computation_code(stacklevel)
#    2996     continue
#    2997 try:
# -> 2998     return inspect.getsource(fr)
#    2999 except OSError:
#    3000     # Try to fine the source if we are in %%time or %%timeit magic.
#    3001     if (
#    3002         fr.f_code.co_filename in {"<timed exec>", "<magic-timeit>"}
#    3003         and "IPython" in sys.modules
#    3004     ):
#
# File /opt/conda/lib/python3.10/inspect.py:1147, in getsource(object)
#    1141 def getsource(object):
#    1142     """Return the text of the source code for an object.
#    1143
#    1144     The argument may be a module, class, method, function, traceback, frame,
#    1145     or code object.  The source code is returned as a single string.  An
#    1146     OSError is raised if the source code cannot be retrieved."""
# -> 1147     lines, lnum = getsourcelines(object)
#    1148     return ''.join(lines)
#
# File /opt/conda/lib/python3.10/inspect.py:1139, in getsourcelines(object)
#    1137     return lines, 0
#    1138 else:
# -> 1139     return getblock(lines[lnum:]), lnum + 1
#
# File /opt/conda/lib/python3.10/inspect.py:1115, in getblock(lines)
#    1113     tokens = tokenize.generate_tokens(iter(lines).__next__)
#    1114     for _token in tokens:
# -> 1115         blockfinder.tokeneater(*_token)
#    1116 except (EndOfBlock, IndentationError):
#    1117     pass
#
# File /opt/conda/lib/python3.10/inspect.py:1059, in BlockFinder.tokeneater(self, type, token, srowcol, erowcol, line)
#    1056     self.last = 1
#    1057     self.body_col0 = None
# -> 1059 def tokeneater(self, type, token, srowcol, erowcol, line):
#    1060     if not self.started and not self.indecorator:
#    1061         # skip any decorators
#    1062         if token == "@":
#
# KeyboardInterrupt:

# %%
#| label: fig-rate_log-flubot-exp-1
#| fig-cap: $\rho(a)$ plot for all instances (B2 period)


import matplotlib.pyplot as plt

for sensitivity, value in data.items():
    print(sensitivity)
    fig, axs = plt.subplots(ncols=1, figsize=(12, 4))
    df_calcs = value["df_calc"]
    for host in local_ips:
        df_calc_host = df_calcs[df_calcs["index"] == host].set_index("ts")
        df_calc_host["rate_log"].plot(label=f'{host}', ax=axs)

    plt.ylim(ymin=0)
    plt.title(f"Sensitivity: {sensitivity}, threshold: {value['threshold']}")
    plt.legend()
    plt.show()
